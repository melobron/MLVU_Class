# %%
import torch, torchvision
from torch import nn
from torch.nn import init
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
from GOPRO_Large2 import GOPRO_Large_train_sharp
from sklearn.model_selection import train_test_split

from einops import rearrange, repeat
from tqdm.notebook import tqdm
from functools import partial
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import math, os, copy


class TimeEmbed(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.dim = dim

    def forward(self, time):
        # Input tensor should be shape of [B, 1] with value of time
        count = self.dim // 2
        embed = torch.arange(count, dtype=time.dtype, device=time.device) / count
        embed = time.unsqueeze(1) * torch.exp(-math.log(1e4) * embed.unsqueeze(0))
        embed = torch.cat([embed.sin(), embed.cos()], dim=-1)
        return embed


class Mish(nn.Module):
    def forward(self, x):
        return x * torch.tanh(F.softplus(x))


class Upsample(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.up = nn.Upsample(scale_factor=2, mode="nearest")
        self.conv = nn.Conv2d(dim, dim, 3, padding=1)

    def forward(self, x):
        return self.conv(self.up(x))


class Downsample(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.conv = nn.Conv2d(dim, dim, 3, 2, 1)

    def forward(self, x):
        return self.conv(x)


class Block(nn.Module):
    def __init__(self, dim, dim_out, groups=32, dropout=0):
        super().__init__()
        self.block = nn.Sequential(
            nn.GroupNorm(groups, dim),
            Mish(),
            nn.Dropout(dropout) if dropout != 0 else nn.Identity(),
            nn.Conv2d(dim, dim_out, 3, padding=1)
        )

    def forward(self, x):
        return self.block(x)


# Linear Multi-head Self-attention
class SelfAtt(nn.Module):
    def __init__(self, channel_dim, num_heads, norm_groups=32):
        super(SelfAtt, self).__init__()
        self.groupnorm = nn.GroupNorm(norm_groups, channel_dim)
        self.channel_dim = channel_dim
        self.num_heads = num_heads
        self.qkv = nn.Conv2d(channel_dim, channel_dim * 3, 1, bias=False)
        self.proj = nn.Conv2d(channel_dim, channel_dim, 1)

    def forward(self, x):
        b, c, h, w = x.size()
        x = self.groupnorm(x)
        qkv = rearrange(self.qkv(x), "b (qkv heads c) h w -> (qkv) b heads c (h w)", heads=self.num_heads, qkv=3)
        queries, keys, values = qkv[0], qkv[1], qkv[2]

        keys = F.softmax(keys, dim=-1)
        att = torch.einsum('bhdn,bhen->bhde', keys, values)
        out = torch.einsum('bhde,bhdn->bhen', att, queries)
        out = rearrange(out, 'b heads c (h w) -> b (heads c) h w', heads=self.num_heads, h=h, w=w)

        return self.proj(out)


class ResBlock(nn.Module):
    def __init__(self, dim, dim_out, time_emb_dim=None, norm_groups=32, num_heads=8, dropout=0, att=True):
        super().__init__()
        self.mlp = nn.Sequential(Mish(), nn.Linear(time_emb_dim, dim_out))
        self.block1 = Block(dim, dim_out, groups=norm_groups)
        self.block2 = Block(dim_out, dim_out, groups=norm_groups, dropout=dropout)
        self.res_conv = nn.Conv2d(dim, dim_out, 1) if dim != dim_out else nn.Identity()
        self.att = att
        self.attn = SelfAtt(dim_out, num_heads=num_heads, norm_groups=norm_groups)

    def forward(self, x, time_emb):
        y = self.block1(x)
        y += self.mlp(time_emb).view(x.shape[0], -1, 1, 1)
        y = self.block2(y)
        x = y + self.res_conv(x)
        if self.att:
            x = self.attn(x)
        return x


class UNet(nn.Module):
    def __init__(self, in_channel=3, out_channel=3, inner_channel=32, norm_groups=32,
                 channel_mults=(1, 2, 4, 8, 8), res_blocks=3, img_size=128, dropout=0):
        super().__init__()

        noise_level_channel = inner_channel
        self.time_embed = nn.Sequential(
            TimeEmbed(inner_channel),
            nn.Linear(inner_channel, inner_channel * 4),
            Mish(),
            nn.Linear(inner_channel * 4, inner_channel)
        )

        num_mults = len(channel_mults)
        pre_channel = inner_channel
        feat_channels = [pre_channel]
        now_res = img_size

        # Downsampling stage of U-net
        downs = [nn.Conv2d(in_channel, inner_channel, kernel_size=3, padding=1)]
        for ind in range(num_mults):
            is_last = (ind == num_mults - 1)
            channel_mult = inner_channel * channel_mults[ind]
            for _ in range(0, res_blocks):
                downs.append(ResBlock(pre_channel, channel_mult, time_emb_dim=noise_level_channel,
                                      norm_groups=norm_groups, dropout=dropout))
                feat_channels.append(channel_mult)
                pre_channel = channel_mult
            if not is_last:
                downs.append(Downsample(pre_channel))
                feat_channels.append(pre_channel)
                now_res = now_res // 2
        self.downs = nn.ModuleList(downs)

        self.mid = nn.ModuleList([
            ResBlock(pre_channel, pre_channel, time_emb_dim=noise_level_channel,
                     norm_groups=norm_groups, dropout=dropout),
            ResBlock(pre_channel, pre_channel, time_emb_dim=noise_level_channel,
                     norm_groups=norm_groups, dropout=dropout, att=False)
        ])

        # Upsampling stage of U-net
        ups = []
        for ind in reversed(range(num_mults)):
            is_last = (ind < 1)
            channel_mult = inner_channel * channel_mults[ind]
            for _ in range(0, res_blocks + 1):
                ups.append(ResBlock(pre_channel + feat_channels.pop(), channel_mult, time_emb_dim=noise_level_channel,
                                    norm_groups=norm_groups, dropout=dropout))
                pre_channel = channel_mult
            if not is_last:
                ups.append(Upsample(pre_channel))
                now_res = now_res * 2

        self.ups = nn.ModuleList(ups)

        self.final_conv = Block(pre_channel, out_channel, groups=norm_groups)

    def forward(self, x, t):
        # Embedding of time step with noise coefficient alpha
        t = self.time_embed(t)

        feats = []
        for layer in self.downs:
            if isinstance(layer, ResBlock):
                x = layer(x, t)
            else:
                x = layer(x)
            feats.append(x)

        for layer in self.mid:
            x = layer(x, t)

        for layer in self.ups:
            if isinstance(layer, ResBlock):
                x = layer(torch.cat((x, feats.pop()), dim=1), t)
            else:
                x = layer(x)

        return self.final_conv(x)


class Diffusion(nn.Module):
    def __init__(self, model, device, channels=3):
        super().__init__()
        self.channels = channels
        self.model = model.to(device)
        self.device = device
        self.loss_func = nn.L1Loss(reduction='sum')

    def make_beta_schedule(self, schedule, n_timestep, linear_start=1e-4, linear_end=2e-2):
        if schedule == 'linear':
            betas = np.linspace(linear_start, linear_end, n_timestep, dtype=np.float64)
        else:
            raise NotImplementedError(schedule)
        return betas

    def set_new_noise_schedule(self, schedule_opt):
        to_torch = partial(torch.tensor, dtype=torch.float32, device=self.device)

        betas = self.make_beta_schedule(
            schedule=schedule_opt['schedule'],
            n_timestep=schedule_opt['n_timestep'],
            linear_start=schedule_opt['linear_start'],
            linear_end=schedule_opt['linear_end'])
        betas = betas.detach().cpu().numpy() if isinstance(betas, torch.Tensor) else betas
        alphas = 1. - betas
        alphas_cumprod = np.cumprod(alphas, axis=0)
        alphas_cumprod_prev = np.append(1., alphas_cumprod[:-1])
        self.sqrt_alphas_cumprod_prev = np.sqrt(np.append(1., alphas_cumprod))

        self.num_timesteps = int(len(betas))

        # Coefficient for forward diffusion q(x_t | x_{t-1}) and others
        self.register_buffer('betas', to_torch(betas))
        self.register_buffer('alphas_cumprod', to_torch(alphas_cumprod))
        self.register_buffer('alphas_cumprod_prev', to_torch(alphas_cumprod_prev))
        self.register_buffer('pred_coef1', to_torch(np.sqrt(1. / alphas_cumprod)))
        self.register_buffer('pred_coef2', to_torch(np.sqrt(1. / alphas_cumprod - 1)))

        # Coefficient for reverse diffusion posterior q(x_{t-1} | x_t, x_0)
        variance = betas * (1. - alphas_cumprod_prev) / (1. - alphas_cumprod)
        self.register_buffer('variance', to_torch(variance))
        # below: log calculation clipped because the posterior variance is 0 at the beginning of the diffusion chain
        self.register_buffer('posterior_log_variance_clipped', to_torch(np.log(np.maximum(variance, 1e-20))))
        self.register_buffer('posterior_mean_coef1',
                             to_torch(betas * np.sqrt(alphas_cumprod_prev) / (1. - alphas_cumprod)))
        self.register_buffer('posterior_mean_coef2',
                             to_torch((1. - alphas_cumprod_prev) * np.sqrt(alphas) / (1. - alphas_cumprod)))

    # Predict desired image x_0 from x_t with noise z_t -> Output is predicted x_0
    def predict_start(self, x_t, t, noise):
        return self.pred_coef1[t] * x_t - self.pred_coef2[t] * noise

    # Compute mean and log variance of posterior(reverse diffusion process) distribution
    def q_posterior(self, x_start, x_t, t):
        posterior_mean = self.posterior_mean_coef1[t] * x_start + self.posterior_mean_coef2[t] * x_t
        posterior_log_variance_clipped = self.posterior_log_variance_clipped[t]
        return posterior_mean, posterior_log_variance_clipped

    # Note that posterior q for reverse diffusion process is conditioned Gaussian distribution q(x_{t-1}|x_t, x_0)
    # Thus to compute desired posterior q, we need original image x_0 in ideal,
    # but it's impossible for actual training procedure -> Thus we reconstruct desired x_0 and use this for posterior
    def p_mean_variance(self, x, t, clip_denoised: bool, condition_x=None):
        batch_size = x.shape[0]
        x_recon = self.predict_start(x, t, noise=self.model(x, torch.full((batch_size, 1), t, device=x.device)))

        if clip_denoised:
            x_recon.clamp_(-1., 1.)

        mean, posterior_log_variance = self.q_posterior(x_start=x_recon, x_t=x, t=t)
        return mean, posterior_log_variance

    # Progress single step of reverse diffusion process
    # Given mean and log variance of posterior, sample reverse diffusion result from the posterior
    @torch.no_grad()
    def p_sample(self, x, t, clip_denoised=True):
        mean, log_variance = self.p_mean_variance(x=x, t=t, clip_denoised=clip_denoised)
        noise = torch.randn_like(x) if t > 0 else torch.zeros_like(x)
        return mean + noise * (0.5 * log_variance).exp()

    # Progress whole reverse diffusion process
    @torch.no_grad()
    def generate(self, x_in):
        img = torch.rand_like(x_in, device=x_in.device)
        for i in reversed(range(0, self.num_timesteps)):
            img = self.p_sample(img, i)
        return img

    # Compute loss to train the model
    def p_losses(self, x_start):
        b, c, h, w = x_start.shape
        t = np.random.randint(1, self.num_timesteps + 1)
        sqrt_alpha = torch.FloatTensor(
            np.random.uniform(self.sqrt_alphas_cumprod_prev[t - 1], self.sqrt_alphas_cumprod_prev[t], size=b)
        ).to(x_start.device)
        sqrt_alpha = sqrt_alpha.view(-1, 1, 1, 1)

        noise = torch.randn_like(x_start).to(x_start.device)
        # Perturbed image obtained by forward diffusion process at random time step t
        x_noisy = sqrt_alpha * x_start + (1 - sqrt_alpha ** 2).sqrt() * noise
        # The model predict actual noise added at time step t
        pred_noise = self.model(x_noisy, t=torch.full((b, 1), t, device=x_start.device))

        return self.loss_func(noise, pred_noise)

    def forward(self, x, *args, **kwargs):
        return self.p_losses(x, *args, **kwargs)


# Class to train & test desired model
class DDPM():
    def __init__(self, device, dataloader, schedule_opt, save_path,
                 load_path=None, load=False, in_channel=3, out_channel=3, inner_channel=32,
                 norm_groups=16, channel_mults=[1, 2, 4, 8, 8], res_blocks=3, dropout=0,
                 img_size=64, lr=1e-4, distributed=False):
        super(DDPM, self).__init__()
        self.dataloader = dataloader
        self.device = device
        self.save_path = save_path
        self.in_channel = in_channel
        self.img_size = img_size

        model = UNet(in_channel, out_channel, inner_channel, norm_groups, channel_mults, res_blocks, img_size)
        self.ddpm = Diffusion(model, device, out_channel)

        # Apply weight initialization & set loss & set noise schedule
        self.ddpm.apply(self.weights_init_orthogonal)
        self.ddpm.set_new_noise_schedule(schedule_opt)

        if distributed:
            assert torch.cuda.is_available()
            self.ddpm = nn.DataParallel(self.ddpm)

        self.optimizer = torch.optim.Adam(self.ddpm.parameters(), lr=lr)

        params = sum(p.numel() for p in self.ddpm.parameters())
        print(f"Number of model parameters : {params}")

        if load:
            self.load(load_path)

    def weights_init_orthogonal(self, m):
        classname = m.__class__.__name__
        if classname.find('Conv') != -1:
            init.orthogonal_(m.weight.data, gain=1)
            if m.bias is not None:
                m.bias.data.zero_()
        elif classname.find('Linear') != -1:
            init.orthogonal_(m.weight.data, gain=1)
            if m.bias is not None:
                m.bias.data.zero_()
        elif classname.find('BatchNorm2d') != -1:
            init.constant_(m.weight.data, 1.0)
            init.constant_(m.bias.data, 0.0)

    def train(self, epoch, verbose):
        fixed_noise = torch.randn(16, self.in_channel, self.img_size, self.img_size).to(self.device)

        for i in range(epoch):
            train_loss = 0
            for index, imgs in enumerate(self.dataloader):
                print('{}th epoch, {}th batch'.format(i, index))
                imgs = imgs.to(self.device)
                b, c, h, w = imgs.shape

                self.optimizer.zero_grad()
                loss = self.ddpm(imgs)
                loss = loss.sum() / int(b * c * h * w)
                loss.backward()
                self.optimizer.step()
                train_loss += loss.item() * b

            if (i + 1) % verbose == 0:
                print(f'Epoch: {i + 1} / loss:{train_loss / len(self.dataloader):.3f}')

                # Save example of test images to check training
                gen_imgs = self.test(fixed_noise)
                gen_imgs = np.transpose(torchvision.utils.make_grid(
                    gen_imgs.detach().cpu(), nrow=4, padding=2, normalize=True), (1, 2, 0))
                matplotlib.image.imsave('Generated_Images2.jpg', gen_imgs.numpy())

                # Save model weight
                self.save(self.save_path)

    def test(self, imgs):
        self.ddpm.eval()
        with torch.no_grad():
            if isinstance(self.ddpm, nn.DataParallel):
                gen_imgs = self.ddpm.module.generate(imgs)
            else:
                gen_imgs = self.ddpm.generate(imgs)
        self.ddpm.train()
        return gen_imgs

    def save(self, save_path):
        network = self.ddpm
        if isinstance(self.ddpm, nn.DataParallel):
            network = network.module
        state_dict = network.state_dict()
        for key, param in state_dict.items():
            state_dict[key] = param.cpu()
        torch.save(state_dict, save_path)

    def load(self, load_path):
        network = self.ddpm
        if isinstance(self.ddpm, nn.DataParallel):
            network = network.module
        network.load_state_dict(torch.load(load_path))
        print("Model loaded successfully")


if __name__ == "__main__":
    batch_size = 1
    img_size = 256
    data = GOPRO_Large_train_sharp(img_size=img_size)
    train_dataset, _ = train_test_split(data, train_size=800, shuffle=True)
    dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2, pin_memory=True)

    cuda = torch.cuda.is_available()
    device = torch.device(f"cuda:{0}" if cuda else "cpu")
    schedule_opt = {'schedule': 'linear', 'n_timestep': 400, 'linear_start': 1e-4, 'linear_end': 0.05}

    ddpm = DDPM(device, dataloader=dataloader, schedule_opt=schedule_opt,  # in_channel=1, out_channel=1,
                save_path='./ddpm2.pt', load_path='./ddpm2.pt', load=False, img_size=img_size, inner_channel=128,
                norm_groups=32, channel_mults=[1, 2, 2, 2], res_blocks=2, dropout=0.2, lr=5 * 1e-5, distributed=False)
    print('Train Start')
    ddpm.train(epoch=100, verbose=50)
# Out:
# Number of model parameters : 36849411
# Train Start
# 0th epoch, 0th batch
# 0th epoch, 1th batch
# 0th epoch, 2th batch
# 0th epoch, 3th batch
# 0th epoch, 4th batch
# 0th epoch, 5th batch
# 0th epoch, 6th batch
# 0th epoch, 7th batch
# 0th epoch, 8th batch
# 0th epoch, 9th batch
# 0th epoch, 10th batch
# 0th epoch, 11th batch
# 0th epoch, 12th batch
# 0th epoch, 13th batch
# 0th epoch, 14th batch
# 0th epoch, 15th batch
# 0th epoch, 16th batch
# 0th epoch, 17th batch
# 0th epoch, 18th batch
# 0th epoch, 19th batch
# 0th epoch, 20th batch
# 0th epoch, 21th batch
# 0th epoch, 22th batch
# 0th epoch, 23th batch
# 0th epoch, 24th batch
# 0th epoch, 25th batch
# 0th epoch, 26th batch
# 0th epoch, 27th batch
# 0th epoch, 28th batch
# 0th epoch, 29th batch
# 0th epoch, 30th batch
# 0th epoch, 31th batch
# 0th epoch, 32th batch
# 0th epoch, 33th batch
# 0th epoch, 34th batch
# 0th epoch, 35th batch
# 0th epoch, 36th batch
# 0th epoch, 37th batch
# 0th epoch, 38th batch
# 0th epoch, 39th batch
# 0th epoch, 40th batch
# 0th epoch, 41th batch
# 0th epoch, 42th batch
# 0th epoch, 43th batch
# 0th epoch, 44th batch
# 0th epoch, 45th batch
# 0th epoch, 46th batch
# 0th epoch, 47th batch
# 0th epoch, 48th batch
# 0th epoch, 49th batch
# 0th epoch, 50th batch
# 0th epoch, 51th batch
# 0th epoch, 52th batch
# 0th epoch, 53th batch
# 0th epoch, 54th batch
# 0th epoch, 55th batch
# 0th epoch, 56th batch
# 0th epoch, 57th batch
# 0th epoch, 58th batch
# 0th epoch, 59th batch
# 0th epoch, 60th batch
# 0th epoch, 61th batch
# 0th epoch, 62th batch
# 0th epoch, 63th batch
# 0th epoch, 64th batch
# 0th epoch, 65th batch
# 0th epoch, 66th batch
# 0th epoch, 67th batch
# 0th epoch, 68th batch
# 0th epoch, 69th batch
# 0th epoch, 70th batch
# 0th epoch, 71th batch
# 0th epoch, 72th batch
# 0th epoch, 73th batch
# 0th epoch, 74th batch
# 0th epoch, 75th batch
# 0th epoch, 76th batch
# 0th epoch, 77th batch
# 0th epoch, 78th batch
# 0th epoch, 79th batch
# 0th epoch, 80th batch
# 0th epoch, 81th batch
# 0th epoch, 82th batch
# 0th epoch, 83th batch
# 0th epoch, 84th batch
# 0th epoch, 85th batch
# 0th epoch, 86th batch
# 0th epoch, 87th batch
# 0th epoch, 88th batch
# 0th epoch, 89th batch
# 0th epoch, 90th batch
# 0th epoch, 91th batch
# 0th epoch, 92th batch
# 0th epoch, 93th batch
# 0th epoch, 94th batch
# 0th epoch, 95th batch
# 0th epoch, 96th batch
# 0th epoch, 97th batch
# 0th epoch, 98th batch
# 0th epoch, 99th batch
# 0th epoch, 100th batch
# 0th epoch, 101th batch
# 0th epoch, 102th batch
# 0th epoch, 103th batch
# 0th epoch, 104th batch
# 0th epoch, 105th batch
# 0th epoch, 106th batch
# 0th epoch, 107th batch
# 0th epoch, 108th batch
# 0th epoch, 109th batch
# 0th epoch, 110th batch
# 0th epoch, 111th batch
# 0th epoch, 112th batch
# 0th epoch, 113th batch
# 0th epoch, 114th batch
# 0th epoch, 115th batch
# 0th epoch, 116th batch
# 0th epoch, 117th batch
# 0th epoch, 118th batch
# 0th epoch, 119th batch
# 0th epoch, 120th batch
# 0th epoch, 121th batch
# 0th epoch, 122th batch
# 0th epoch, 123th batch
# 0th epoch, 124th batch
# 0th epoch, 125th batch
# 0th epoch, 126th batch
# 0th epoch, 127th batch
# 0th epoch, 128th batch
# 0th epoch, 129th batch
# 0th epoch, 130th batch
# 0th epoch, 131th batch
# 0th epoch, 132th batch
# 0th epoch, 133th batch
# 0th epoch, 134th batch
# 0th epoch, 135th batch
# 0th epoch, 136th batch
# 0th epoch, 137th batch
# 0th epoch, 138th batch
# 0th epoch, 139th batch
# 0th epoch, 140th batch
# 0th epoch, 141th batch
# 0th epoch, 142th batch
# 0th epoch, 143th batch
# 0th epoch, 144th batch
# 0th epoch, 145th batch
# 0th epoch, 146th batch
# 0th epoch, 147th batch
# 0th epoch, 148th batch
# 0th epoch, 149th batch
# 0th epoch, 150th batch
# 0th epoch, 151th batch
# 0th epoch, 152th batch
# 0th epoch, 153th batch
# 0th epoch, 154th batch
# 0th epoch, 155th batch
# 0th epoch, 156th batch
# 0th epoch, 157th batch
# 0th epoch, 158th batch
# 0th epoch, 159th batch
# 0th epoch, 160th batch
# 0th epoch, 161th batch
# 0th epoch, 162th batch
# 0th epoch, 163th batch
# 0th epoch, 164th batch
# 0th epoch, 165th batch
# 0th epoch, 166th batch
# 0th epoch, 167th batch
# 0th epoch, 168th batch
# 0th epoch, 169th batch
# 0th epoch, 170th batch
# 0th epoch, 171th batch
# 0th epoch, 172th batch
# 0th epoch, 173th batch
# 0th epoch, 174th batch
# 0th epoch, 175th batch
# 0th epoch, 176th batch
# 0th epoch, 177th batch
# 0th epoch, 178th batch
# 0th epoch, 179th batch
# 0th epoch, 180th batch
# 0th epoch, 181th batch
# 0th epoch, 182th batch
# 0th epoch, 183th batch
# 0th epoch, 184th batch
# 0th epoch, 185th batch
# 0th epoch, 186th batch
# 0th epoch, 187th batch
# 0th epoch, 188th batch
# 0th epoch, 189th batch
# 0th epoch, 190th batch
# 0th epoch, 191th batch
# 0th epoch, 192th batch
# 0th epoch, 193th batch
# 0th epoch, 194th batch
# 0th epoch, 195th batch
# 0th epoch, 196th batch
# 0th epoch, 197th batch
# 0th epoch, 198th batch
# 0th epoch, 199th batch
# 0th epoch, 200th batch
# 0th epoch, 201th batch
# 0th epoch, 202th batch
# 0th epoch, 203th batch
# 0th epoch, 204th batch
# 0th epoch, 205th batch
# 0th epoch, 206th batch
# 0th epoch, 207th batch
# 0th epoch, 208th batch
# 0th epoch, 209th batch
# 0th epoch, 210th batch
# 0th epoch, 211th batch
# 0th epoch, 212th batch
# 0th epoch, 213th batch
# 0th epoch, 214th batch
# 0th epoch, 215th batch
# 0th epoch, 216th batch
# 0th epoch, 217th batch
# 0th epoch, 218th batch
# 0th epoch, 219th batch
# 0th epoch, 220th batch
# 0th epoch, 221th batch
# 0th epoch, 222th batch
# 0th epoch, 223th batch
# 0th epoch, 224th batch
# 0th epoch, 225th batch
# 0th epoch, 226th batch
# 0th epoch, 227th batch
# 0th epoch, 228th batch
# 0th epoch, 229th batch
# 0th epoch, 230th batch
# 0th epoch, 231th batch
# 0th epoch, 232th batch
# 0th epoch, 233th batch
# 0th epoch, 234th batch
# 0th epoch, 235th batch
# 0th epoch, 236th batch
# 0th epoch, 237th batch
# 0th epoch, 238th batch
# 0th epoch, 239th batch
# 0th epoch, 240th batch
# 0th epoch, 241th batch
# 0th epoch, 242th batch
# 0th epoch, 243th batch
# 0th epoch, 244th batch
# 0th epoch, 245th batch
# 0th epoch, 246th batch
# 0th epoch, 247th batch
# 0th epoch, 248th batch
# 0th epoch, 249th batch
# 0th epoch, 250th batch
# 0th epoch, 251th batch
# 0th epoch, 252th batch
# 0th epoch, 253th batch
# 0th epoch, 254th batch
# 0th epoch, 255th batch
# 0th epoch, 256th batch
# 0th epoch, 257th batch
# 0th epoch, 258th batch
# 0th epoch, 259th batch
# 0th epoch, 260th batch
# 0th epoch, 261th batch
# 0th epoch, 262th batch
# 0th epoch, 263th batch
# 0th epoch, 264th batch
# 0th epoch, 265th batch
# 0th epoch, 266th batch
# 0th epoch, 267th batch
# 0th epoch, 268th batch
# 0th epoch, 269th batch
# 0th epoch, 270th batch
# 0th epoch, 271th batch
# 0th epoch, 272th batch
# 0th epoch, 273th batch
# 0th epoch, 274th batch
# 0th epoch, 275th batch
# 0th epoch, 276th batch
# 0th epoch, 277th batch
# 0th epoch, 278th batch
# 0th epoch, 279th batch
# 0th epoch, 280th batch
# 0th epoch, 281th batch
# 0th epoch, 282th batch
# 0th epoch, 283th batch
# 0th epoch, 284th batch
# 0th epoch, 285th batch
# 0th epoch, 286th batch
# 0th epoch, 287th batch
# 0th epoch, 288th batch
# 0th epoch, 289th batch
# 0th epoch, 290th batch
# 0th epoch, 291th batch
# 0th epoch, 292th batch
# 0th epoch, 293th batch
# 0th epoch, 294th batch
# 0th epoch, 295th batch
# 0th epoch, 296th batch
# 0th epoch, 297th batch
# 0th epoch, 298th batch
# 0th epoch, 299th batch
# 0th epoch, 300th batch
# 0th epoch, 301th batch
# 0th epoch, 302th batch
# 0th epoch, 303th batch
# 0th epoch, 304th batch
# 0th epoch, 305th batch
# 0th epoch, 306th batch
# 0th epoch, 307th batch
# 0th epoch, 308th batch
# 0th epoch, 309th batch
# 0th epoch, 310th batch
# 0th epoch, 311th batch
# 0th epoch, 312th batch
# 0th epoch, 313th batch
# 0th epoch, 314th batch
# 0th epoch, 315th batch
# 0th epoch, 316th batch
# 0th epoch, 317th batch
# 0th epoch, 318th batch
# 0th epoch, 319th batch
# 0th epoch, 320th batch
# 0th epoch, 321th batch
# 0th epoch, 322th batch
# 0th epoch, 323th batch
# 0th epoch, 324th batch
# 0th epoch, 325th batch
# 0th epoch, 326th batch
# 0th epoch, 327th batch
# 0th epoch, 328th batch
# 0th epoch, 329th batch
# 0th epoch, 330th batch
# 0th epoch, 331th batch
# 0th epoch, 332th batch
# 0th epoch, 333th batch
# 0th epoch, 334th batch
# 0th epoch, 335th batch
# 0th epoch, 336th batch
# 0th epoch, 337th batch
# 0th epoch, 338th batch
# 0th epoch, 339th batch
# 0th epoch, 340th batch
# 0th epoch, 341th batch
# 0th epoch, 342th batch
# 0th epoch, 343th batch
# 0th epoch, 344th batch
# 0th epoch, 345th batch
# 0th epoch, 346th batch
# 0th epoch, 347th batch
# 0th epoch, 348th batch
# 0th epoch, 349th batch
# 0th epoch, 350th batch
# 0th epoch, 351th batch
# 0th epoch, 352th batch
# 0th epoch, 353th batch
# 0th epoch, 354th batch
# 0th epoch, 355th batch
# 0th epoch, 356th batch
# 0th epoch, 357th batch
# 0th epoch, 358th batch
# 0th epoch, 359th batch
# 0th epoch, 360th batch
# 0th epoch, 361th batch
# 0th epoch, 362th batch
# 0th epoch, 363th batch
# 0th epoch, 364th batch
# 0th epoch, 365th batch
# 0th epoch, 366th batch
# 0th epoch, 367th batch
# 0th epoch, 368th batch
# 0th epoch, 369th batch
# 0th epoch, 370th batch
# 0th epoch, 371th batch
# 0th epoch, 372th batch
# 0th epoch, 373th batch
# 0th epoch, 374th batch
# 0th epoch, 375th batch
# 0th epoch, 376th batch
# 0th epoch, 377th batch
# 0th epoch, 378th batch
# 0th epoch, 379th batch
# 0th epoch, 380th batch
# 0th epoch, 381th batch
# 0th epoch, 382th batch
# 0th epoch, 383th batch
# 0th epoch, 384th batch
# 0th epoch, 385th batch
# 0th epoch, 386th batch
# 0th epoch, 387th batch
# 0th epoch, 388th batch
# 0th epoch, 389th batch
# 0th epoch, 390th batch
# 0th epoch, 391th batch
# 0th epoch, 392th batch
# 0th epoch, 393th batch
# 0th epoch, 394th batch
# 0th epoch, 395th batch
# 0th epoch, 396th batch
# 0th epoch, 397th batch
# 0th epoch, 398th batch
# 0th epoch, 399th batch
# 0th epoch, 400th batch
# 0th epoch, 401th batch
# 0th epoch, 402th batch
# 0th epoch, 403th batch
# 0th epoch, 404th batch
# 0th epoch, 405th batch
# 0th epoch, 406th batch
# 0th epoch, 407th batch
# 0th epoch, 408th batch
# 0th epoch, 409th batch
# 0th epoch, 410th batch
# 0th epoch, 411th batch
# 0th epoch, 412th batch
# 0th epoch, 413th batch
# 0th epoch, 414th batch
# 0th epoch, 415th batch
# 0th epoch, 416th batch
# 0th epoch, 417th batch
# 0th epoch, 418th batch
# 0th epoch, 419th batch
# 0th epoch, 420th batch
# 0th epoch, 421th batch
# 0th epoch, 422th batch
# 0th epoch, 423th batch
# 0th epoch, 424th batch
# 0th epoch, 425th batch
# 0th epoch, 426th batch
# 0th epoch, 427th batch
# 0th epoch, 428th batch
# 0th epoch, 429th batch
# 0th epoch, 430th batch
# 0th epoch, 431th batch
# 0th epoch, 432th batch
# 0th epoch, 433th batch
# 0th epoch, 434th batch
# 0th epoch, 435th batch
# 0th epoch, 436th batch
# 0th epoch, 437th batch
# 0th epoch, 438th batch
# 0th epoch, 439th batch
# 0th epoch, 440th batch
# 0th epoch, 441th batch
# 0th epoch, 442th batch
# 0th epoch, 443th batch
# 0th epoch, 444th batch
# 0th epoch, 445th batch
# 0th epoch, 446th batch
# 0th epoch, 447th batch
# 0th epoch, 448th batch
# 0th epoch, 449th batch
# 0th epoch, 450th batch
# 0th epoch, 451th batch
# 0th epoch, 452th batch
# 0th epoch, 453th batch
# 0th epoch, 454th batch
# 0th epoch, 455th batch
# 0th epoch, 456th batch
# 0th epoch, 457th batch
# 0th epoch, 458th batch
# 0th epoch, 459th batch
# 0th epoch, 460th batch
# 0th epoch, 461th batch
# 0th epoch, 462th batch
# 0th epoch, 463th batch
# 0th epoch, 464th batch
# 0th epoch, 465th batch
# 0th epoch, 466th batch
# 0th epoch, 467th batch
# 0th epoch, 468th batch
# 0th epoch, 469th batch
# 0th epoch, 470th batch
# 0th epoch, 471th batch
# 0th epoch, 472th batch
# 0th epoch, 473th batch
# 0th epoch, 474th batch
# 0th epoch, 475th batch
# 0th epoch, 476th batch
# 0th epoch, 477th batch
# 0th epoch, 478th batch
# 0th epoch, 479th batch
# 0th epoch, 480th batch
# 0th epoch, 481th batch
# 0th epoch, 482th batch
# 0th epoch, 483th batch
# 0th epoch, 484th batch
# 0th epoch, 485th batch
# 0th epoch, 486th batch
# 0th epoch, 487th batch
# 0th epoch, 488th batch
# 0th epoch, 489th batch
# 0th epoch, 490th batch
# 0th epoch, 491th batch
# 0th epoch, 492th batch
# 0th epoch, 493th batch
# 0th epoch, 494th batch
# 0th epoch, 495th batch
# 0th epoch, 496th batch
# 0th epoch, 497th batch
# 0th epoch, 498th batch
# 0th epoch, 499th batch
# 0th epoch, 500th batch
# 0th epoch, 501th batch
# 0th epoch, 502th batch
# 0th epoch, 503th batch
# 0th epoch, 504th batch
# 0th epoch, 505th batch
# 0th epoch, 506th batch
# 0th epoch, 507th batch
# 0th epoch, 508th batch
# 0th epoch, 509th batch
# 0th epoch, 510th batch
# 0th epoch, 511th batch
# 0th epoch, 512th batch
# 0th epoch, 513th batch
# 0th epoch, 514th batch
# 0th epoch, 515th batch
# 0th epoch, 516th batch
# 0th epoch, 517th batch
# 0th epoch, 518th batch
# 0th epoch, 519th batch
# 0th epoch, 520th batch
# 0th epoch, 521th batch
# 0th epoch, 522th batch
# 0th epoch, 523th batch
# 0th epoch, 524th batch
# 0th epoch, 525th batch
# 0th epoch, 526th batch
# 0th epoch, 527th batch
# 0th epoch, 528th batch
# 0th epoch, 529th batch
# 0th epoch, 530th batch
# 0th epoch, 531th batch
# 0th epoch, 532th batch
# 0th epoch, 533th batch
# 0th epoch, 534th batch
# 0th epoch, 535th batch
# 0th epoch, 536th batch
# 0th epoch, 537th batch
# 0th epoch, 538th batch
# 0th epoch, 539th batch
# 0th epoch, 540th batch
# 0th epoch, 541th batch
# 0th epoch, 542th batch
# 0th epoch, 543th batch
# 0th epoch, 544th batch
# 0th epoch, 545th batch
# 0th epoch, 546th batch
# 0th epoch, 547th batch
# 0th epoch, 548th batch
# 0th epoch, 549th batch
# 0th epoch, 550th batch
# 0th epoch, 551th batch
# 0th epoch, 552th batch
# 0th epoch, 553th batch
# 0th epoch, 554th batch
# 0th epoch, 555th batch
# 0th epoch, 556th batch
# 0th epoch, 557th batch
# 0th epoch, 558th batch
# 0th epoch, 559th batch
# 0th epoch, 560th batch
# 0th epoch, 561th batch
# 0th epoch, 562th batch
# 0th epoch, 563th batch
# 0th epoch, 564th batch
# 0th epoch, 565th batch
# 0th epoch, 566th batch
# 0th epoch, 567th batch
# 0th epoch, 568th batch
# 0th epoch, 569th batch
# 0th epoch, 570th batch
# 0th epoch, 571th batch
# 0th epoch, 572th batch
# 0th epoch, 573th batch
# 0th epoch, 574th batch
# 0th epoch, 575th batch
# 0th epoch, 576th batch
# 0th epoch, 577th batch
# 0th epoch, 578th batch
# 0th epoch, 579th batch
# 0th epoch, 580th batch
# 0th epoch, 581th batch
# 0th epoch, 582th batch
# 0th epoch, 583th batch
# 0th epoch, 584th batch
# 0th epoch, 585th batch
# 0th epoch, 586th batch
# 0th epoch, 587th batch
# 0th epoch, 588th batch
# 0th epoch, 589th batch
# 0th epoch, 590th batch
# 0th epoch, 591th batch
# 0th epoch, 592th batch
# 0th epoch, 593th batch
# 0th epoch, 594th batch
# 0th epoch, 595th batch
# 0th epoch, 596th batch
# 0th epoch, 597th batch
# 0th epoch, 598th batch
# 0th epoch, 599th batch
# 0th epoch, 600th batch
# 0th epoch, 601th batch
# 0th epoch, 602th batch
# 0th epoch, 603th batch
# 0th epoch, 604th batch
# 0th epoch, 605th batch
# 0th epoch, 606th batch
# 0th epoch, 607th batch
# 0th epoch, 608th batch
# 0th epoch, 609th batch
# 0th epoch, 610th batch
# 0th epoch, 611th batch
# 0th epoch, 612th batch
# 0th epoch, 613th batch
# 0th epoch, 614th batch
# 0th epoch, 615th batch
# 0th epoch, 616th batch
# 0th epoch, 617th batch
# 0th epoch, 618th batch
# 0th epoch, 619th batch
# 0th epoch, 620th batch
# 0th epoch, 621th batch
# 0th epoch, 622th batch
# 0th epoch, 623th batch
# 0th epoch, 624th batch
# 0th epoch, 625th batch
# 0th epoch, 626th batch
# 0th epoch, 627th batch
# 0th epoch, 628th batch
# 0th epoch, 629th batch
# 0th epoch, 630th batch
# 0th epoch, 631th batch
# 0th epoch, 632th batch
# 0th epoch, 633th batch
# 0th epoch, 634th batch
# 0th epoch, 635th batch
# 0th epoch, 636th batch
# 0th epoch, 637th batch
# 0th epoch, 638th batch
# 0th epoch, 639th batch
# 0th epoch, 640th batch
# 0th epoch, 641th batch
# 0th epoch, 642th batch
# 0th epoch, 643th batch
# 0th epoch, 644th batch
# 0th epoch, 645th batch
# 0th epoch, 646th batch
# 0th epoch, 647th batch
# 0th epoch, 648th batch
# 0th epoch, 649th batch
# 0th epoch, 650th batch
# 0th epoch, 651th batch
# 0th epoch, 652th batch
# 0th epoch, 653th batch
# 0th epoch, 654th batch
# 0th epoch, 655th batch
# 0th epoch, 656th batch
# 0th epoch, 657th batch
# 0th epoch, 658th batch
# 0th epoch, 659th batch
# 0th epoch, 660th batch
# 0th epoch, 661th batch
# 0th epoch, 662th batch
# 0th epoch, 663th batch
# 0th epoch, 664th batch
# 0th epoch, 665th batch
# 0th epoch, 666th batch
# 0th epoch, 667th batch
# 0th epoch, 668th batch
# 0th epoch, 669th batch
# 0th epoch, 670th batch
# 0th epoch, 671th batch
# 0th epoch, 672th batch
# 0th epoch, 673th batch
# 0th epoch, 674th batch
# 0th epoch, 675th batch
# 0th epoch, 676th batch
# 0th epoch, 677th batch
# 0th epoch, 678th batch
# 0th epoch, 679th batch
# 0th epoch, 680th batch
# 0th epoch, 681th batch
# 0th epoch, 682th batch
# 0th epoch, 683th batch
# 0th epoch, 684th batch
# 0th epoch, 685th batch
# 0th epoch, 686th batch
# 0th epoch, 687th batch
# 0th epoch, 688th batch
# 0th epoch, 689th batch
# 0th epoch, 690th batch
# 0th epoch, 691th batch
# 0th epoch, 692th batch
# 0th epoch, 693th batch
# 0th epoch, 694th batch
# 0th epoch, 695th batch
# 0th epoch, 696th batch
# 0th epoch, 697th batch
# 0th epoch, 698th batch
# 0th epoch, 699th batch
# 0th epoch, 700th batch
# 0th epoch, 701th batch
# 0th epoch, 702th batch
# 0th epoch, 703th batch
# 0th epoch, 704th batch
# 0th epoch, 705th batch
# 0th epoch, 706th batch
# 0th epoch, 707th batch
# 0th epoch, 708th batch
# 0th epoch, 709th batch
# 0th epoch, 710th batch
# 0th epoch, 711th batch
# 0th epoch, 712th batch
# 0th epoch, 713th batch
# 0th epoch, 714th batch
# 0th epoch, 715th batch
# 0th epoch, 716th batch
# 0th epoch, 717th batch
# 0th epoch, 718th batch
# 0th epoch, 719th batch
# 0th epoch, 720th batch
# 0th epoch, 721th batch
# 0th epoch, 722th batch
# 0th epoch, 723th batch
# 0th epoch, 724th batch
# 0th epoch, 725th batch
# 0th epoch, 726th batch
# 0th epoch, 727th batch
# 0th epoch, 728th batch
# 0th epoch, 729th batch
# 0th epoch, 730th batch
# 0th epoch, 731th batch
# 0th epoch, 732th batch
# 0th epoch, 733th batch
# 0th epoch, 734th batch
# 0th epoch, 735th batch
# 0th epoch, 736th batch
# 0th epoch, 737th batch
# 0th epoch, 738th batch
# 0th epoch, 739th batch
# 0th epoch, 740th batch
# 0th epoch, 741th batch
# 0th epoch, 742th batch
# 0th epoch, 743th batch
# 0th epoch, 744th batch
# 0th epoch, 745th batch
# 0th epoch, 746th batch
# 0th epoch, 747th batch
# 0th epoch, 748th batch
# 0th epoch, 749th batch
# 0th epoch, 750th batch
# 0th epoch, 751th batch
# 0th epoch, 752th batch
# 0th epoch, 753th batch
# 0th epoch, 754th batch
# 0th epoch, 755th batch
# 0th epoch, 756th batch
# 0th epoch, 757th batch
# 0th epoch, 758th batch
# 0th epoch, 759th batch
# 0th epoch, 760th batch
# 0th epoch, 761th batch
# 0th epoch, 762th batch
# 0th epoch, 763th batch
# 0th epoch, 764th batch
# 0th epoch, 765th batch
# 0th epoch, 766th batch
# 0th epoch, 767th batch
# 0th epoch, 768th batch
# 0th epoch, 769th batch
# 0th epoch, 770th batch
# 0th epoch, 771th batch
# 0th epoch, 772th batch
# 0th epoch, 773th batch
# 0th epoch, 774th batch
# 0th epoch, 775th batch
# 0th epoch, 776th batch
# 0th epoch, 777th batch
# 0th epoch, 778th batch
# 0th epoch, 779th batch
# 0th epoch, 780th batch
# 0th epoch, 781th batch
# 0th epoch, 782th batch
# 0th epoch, 783th batch
# 0th epoch, 784th batch
# 0th epoch, 785th batch
# 0th epoch, 786th batch
# 0th epoch, 787th batch
# 0th epoch, 788th batch
# 0th epoch, 789th batch
# 0th epoch, 790th batch
# 0th epoch, 791th batch
# 0th epoch, 792th batch
# 0th epoch, 793th batch
# 0th epoch, 794th batch
# 0th epoch, 795th batch
# 0th epoch, 796th batch
# 0th epoch, 797th batch
# 0th epoch, 798th batch
# 0th epoch, 799th batch
# 1th epoch, 0th batch
# 1th epoch, 1th batch
# 1th epoch, 2th batch
# 1th epoch, 3th batch
# 1th epoch, 4th batch
# 1th epoch, 5th batch
# 1th epoch, 6th batch
# 1th epoch, 7th batch
# 1th epoch, 8th batch
# 1th epoch, 9th batch
# 1th epoch, 10th batch
# 1th epoch, 11th batch
# 1th epoch, 12th batch
# 1th epoch, 13th batch
# 1th epoch, 14th batch
# 1th epoch, 15th batch
# 1th epoch, 16th batch
# 1th epoch, 17th batch
# 1th epoch, 18th batch
# 1th epoch, 19th batch
# 1th epoch, 20th batch
# 1th epoch, 21th batch
# 1th epoch, 22th batch
# 1th epoch, 23th batch
# 1th epoch, 24th batch
# 1th epoch, 25th batch
# 1th epoch, 26th batch
# 1th epoch, 27th batch
# 1th epoch, 28th batch
# 1th epoch, 29th batch
# 1th epoch, 30th batch
# 1th epoch, 31th batch
# 1th epoch, 32th batch
# 1th epoch, 33th batch
# 1th epoch, 34th batch
# 1th epoch, 35th batch
# 1th epoch, 36th batch
# 1th epoch, 37th batch
# 1th epoch, 38th batch
# 1th epoch, 39th batch
# 1th epoch, 40th batch
# 1th epoch, 41th batch
# 1th epoch, 42th batch
# 1th epoch, 43th batch
# 1th epoch, 44th batch
# 1th epoch, 45th batch
# 1th epoch, 46th batch
# 1th epoch, 47th batch
# 1th epoch, 48th batch
# 1th epoch, 49th batch
# 1th epoch, 50th batch
# 1th epoch, 51th batch
# 1th epoch, 52th batch
# 1th epoch, 53th batch
# 1th epoch, 54th batch
# 1th epoch, 55th batch
# 1th epoch, 56th batch
# 1th epoch, 57th batch
# 1th epoch, 58th batch
# 1th epoch, 59th batch
# 1th epoch, 60th batch
# 1th epoch, 61th batch
# 1th epoch, 62th batch
# 1th epoch, 63th batch
# 1th epoch, 64th batch
# 1th epoch, 65th batch
# 1th epoch, 66th batch
# 1th epoch, 67th batch
# 1th epoch, 68th batch
# 1th epoch, 69th batch
# 1th epoch, 70th batch
# 1th epoch, 71th batch
# 1th epoch, 72th batch
# 1th epoch, 73th batch
# 1th epoch, 74th batch
# 1th epoch, 75th batch
# 1th epoch, 76th batch
# 1th epoch, 77th batch
# 1th epoch, 78th batch
# 1th epoch, 79th batch
# 1th epoch, 80th batch
# 1th epoch, 81th batch
# 1th epoch, 82th batch
# 1th epoch, 83th batch
# 1th epoch, 84th batch
# 1th epoch, 85th batch
# 1th epoch, 86th batch
# 1th epoch, 87th batch
# 1th epoch, 88th batch
# 1th epoch, 89th batch
# 1th epoch, 90th batch
# 1th epoch, 91th batch
# 1th epoch, 92th batch
# 1th epoch, 93th batch
# 1th epoch, 94th batch
# 1th epoch, 95th batch
# 1th epoch, 96th batch
# 1th epoch, 97th batch
# 1th epoch, 98th batch
# 1th epoch, 99th batch
# 1th epoch, 100th batch
# 1th epoch, 101th batch
# 1th epoch, 102th batch
# 1th epoch, 103th batch
# 1th epoch, 104th batch
# 1th epoch, 105th batch
# 1th epoch, 106th batch
# 1th epoch, 107th batch
# 1th epoch, 108th batch
# 1th epoch, 109th batch
# 1th epoch, 110th batch
# 1th epoch, 111th batch
# 1th epoch, 112th batch
# 1th epoch, 113th batch
# 1th epoch, 114th batch
# 1th epoch, 115th batch
# 1th epoch, 116th batch
# 1th epoch, 117th batch
# 1th epoch, 118th batch
# 1th epoch, 119th batch
# 1th epoch, 120th batch
# 1th epoch, 121th batch
# 1th epoch, 122th batch
# 1th epoch, 123th batch
# 1th epoch, 124th batch
# 1th epoch, 125th batch
# 1th epoch, 126th batch
# 1th epoch, 127th batch
# 1th epoch, 128th batch
# 1th epoch, 129th batch
# 1th epoch, 130th batch
# 1th epoch, 131th batch
# 1th epoch, 132th batch
# 1th epoch, 133th batch
# 1th epoch, 134th batch
# 1th epoch, 135th batch
# 1th epoch, 136th batch
# 1th epoch, 137th batch
# 1th epoch, 138th batch
# 1th epoch, 139th batch
# 1th epoch, 140th batch
# 1th epoch, 141th batch
# 1th epoch, 142th batch
# 1th epoch, 143th batch
# 1th epoch, 144th batch
# 1th epoch, 145th batch
# 1th epoch, 146th batch
# 1th epoch, 147th batch
# 1th epoch, 148th batch
# 1th epoch, 149th batch
# 1th epoch, 150th batch
# 1th epoch, 151th batch
# 1th epoch, 152th batch
# 1th epoch, 153th batch
# 1th epoch, 154th batch
# 1th epoch, 155th batch
# 1th epoch, 156th batch
# 1th epoch, 157th batch
# 1th epoch, 158th batch
# 1th epoch, 159th batch
# 1th epoch, 160th batch
# 1th epoch, 161th batch
# 1th epoch, 162th batch
# 1th epoch, 163th batch
# 1th epoch, 164th batch
# 1th epoch, 165th batch
# 1th epoch, 166th batch
# 1th epoch, 167th batch
# 1th epoch, 168th batch
# 1th epoch, 169th batch
# 1th epoch, 170th batch
# 1th epoch, 171th batch
# 1th epoch, 172th batch
# 1th epoch, 173th batch
# 1th epoch, 174th batch
# 1th epoch, 175th batch
# 1th epoch, 176th batch
# 1th epoch, 177th batch
# 1th epoch, 178th batch
# 1th epoch, 179th batch
# 1th epoch, 180th batch
# 1th epoch, 181th batch
# 1th epoch, 182th batch
# 1th epoch, 183th batch
# 1th epoch, 184th batch
# 1th epoch, 185th batch
# 1th epoch, 186th batch
# 1th epoch, 187th batch
# 1th epoch, 188th batch
# 1th epoch, 189th batch
# 1th epoch, 190th batch
# 1th epoch, 191th batch
# 1th epoch, 192th batch
# 1th epoch, 193th batch
# 1th epoch, 194th batch
# 1th epoch, 195th batch
# 1th epoch, 196th batch
# 1th epoch, 197th batch
# 1th epoch, 198th batch
# 1th epoch, 199th batch
# 1th epoch, 200th batch
# 1th epoch, 201th batch
# 1th epoch, 202th batch
# 1th epoch, 203th batch
# 1th epoch, 204th batch
# 1th epoch, 205th batch
# 1th epoch, 206th batch
# 1th epoch, 207th batch
# 1th epoch, 208th batch
# 1th epoch, 209th batch
# 1th epoch, 210th batch
# 1th epoch, 211th batch
# 1th epoch, 212th batch
# 1th epoch, 213th batch
# 1th epoch, 214th batch
# 1th epoch, 215th batch
# 1th epoch, 216th batch
# 1th epoch, 217th batch
# 1th epoch, 218th batch
# 1th epoch, 219th batch
# 1th epoch, 220th batch
# 1th epoch, 221th batch
# 1th epoch, 222th batch
# 1th epoch, 223th batch
# 1th epoch, 224th batch
# 1th epoch, 225th batch
# 1th epoch, 226th batch
# 1th epoch, 227th batch
# 1th epoch, 228th batch
# 1th epoch, 229th batch
# 1th epoch, 230th batch
# 1th epoch, 231th batch
# 1th epoch, 232th batch
# 1th epoch, 233th batch
# 1th epoch, 234th batch
# 1th epoch, 235th batch
# 1th epoch, 236th batch
# 1th epoch, 237th batch
# 1th epoch, 238th batch
# 1th epoch, 239th batch
# 1th epoch, 240th batch
# 1th epoch, 241th batch
# 1th epoch, 242th batch
# 1th epoch, 243th batch
# 1th epoch, 244th batch
# 1th epoch, 245th batch
# 1th epoch, 246th batch
# 1th epoch, 247th batch
# 1th epoch, 248th batch
# 1th epoch, 249th batch
# 1th epoch, 250th batch
# 1th epoch, 251th batch
# 1th epoch, 252th batch
# 1th epoch, 253th batch
# 1th epoch, 254th batch
# 1th epoch, 255th batch
# 1th epoch, 256th batch
# 1th epoch, 257th batch
# 1th epoch, 258th batch
# 1th epoch, 259th batch
# 1th epoch, 260th batch
# 1th epoch, 261th batch
# 1th epoch, 262th batch
# 1th epoch, 263th batch
# 1th epoch, 264th batch
# 1th epoch, 265th batch
# 1th epoch, 266th batch
# 1th epoch, 267th batch
# 1th epoch, 268th batch
# 1th epoch, 269th batch
# 1th epoch, 270th batch
# 1th epoch, 271th batch
# 1th epoch, 272th batch
# 1th epoch, 273th batch
# 1th epoch, 274th batch
# 1th epoch, 275th batch
# 1th epoch, 276th batch
# 1th epoch, 277th batch
# 1th epoch, 278th batch
# 1th epoch, 279th batch
# 1th epoch, 280th batch
# 1th epoch, 281th batch
# 1th epoch, 282th batch
# 1th epoch, 283th batch
# 1th epoch, 284th batch
# 1th epoch, 285th batch
# 1th epoch, 286th batch
# 1th epoch, 287th batch
# 1th epoch, 288th batch
# 1th epoch, 289th batch
# 1th epoch, 290th batch
# 1th epoch, 291th batch
# 1th epoch, 292th batch
# 1th epoch, 293th batch
# 1th epoch, 294th batch
# 1th epoch, 295th batch
# 1th epoch, 296th batch
# 1th epoch, 297th batch
# 1th epoch, 298th batch
# 1th epoch, 299th batch
# 1th epoch, 300th batch
# 1th epoch, 301th batch
# 1th epoch, 302th batch
# 1th epoch, 303th batch
# 1th epoch, 304th batch
# 1th epoch, 305th batch
# 1th epoch, 306th batch
# 1th epoch, 307th batch
# 1th epoch, 308th batch
# 1th epoch, 309th batch
# 1th epoch, 310th batch
# 1th epoch, 311th batch
# 1th epoch, 312th batch
# 1th epoch, 313th batch
# 1th epoch, 314th batch
# 1th epoch, 315th batch
# 1th epoch, 316th batch
# 1th epoch, 317th batch
# 1th epoch, 318th batch
# 1th epoch, 319th batch
# 1th epoch, 320th batch
# 1th epoch, 321th batch
# 1th epoch, 322th batch
# 1th epoch, 323th batch
# 1th epoch, 324th batch
# 1th epoch, 325th batch
# 1th epoch, 326th batch
# 1th epoch, 327th batch
# 1th epoch, 328th batch
# 1th epoch, 329th batch
# 1th epoch, 330th batch
# 1th epoch, 331th batch
# 1th epoch, 332th batch
# 1th epoch, 333th batch
# 1th epoch, 334th batch
# 1th epoch, 335th batch
# 1th epoch, 336th batch
# 1th epoch, 337th batch
# 1th epoch, 338th batch
# 1th epoch, 339th batch
# 1th epoch, 340th batch
# 1th epoch, 341th batch
# 1th epoch, 342th batch
# 1th epoch, 343th batch
# 1th epoch, 344th batch
# 1th epoch, 345th batch
# 1th epoch, 346th batch
# 1th epoch, 347th batch
# 1th epoch, 348th batch
# 1th epoch, 349th batch
# 1th epoch, 350th batch
# 1th epoch, 351th batch
# 1th epoch, 352th batch
# 1th epoch, 353th batch
# 1th epoch, 354th batch
# 1th epoch, 355th batch
# 1th epoch, 356th batch
# 1th epoch, 357th batch
# 1th epoch, 358th batch
# 1th epoch, 359th batch
# 1th epoch, 360th batch
# 1th epoch, 361th batch
# 1th epoch, 362th batch
# 1th epoch, 363th batch
# 1th epoch, 364th batch
# 1th epoch, 365th batch
# 1th epoch, 366th batch
# 1th epoch, 367th batch
# 1th epoch, 368th batch
# 1th epoch, 369th batch
# 1th epoch, 370th batch
# 1th epoch, 371th batch
# 1th epoch, 372th batch
# 1th epoch, 373th batch
# 1th epoch, 374th batch
# 1th epoch, 375th batch
# 1th epoch, 376th batch
# 1th epoch, 377th batch
# 1th epoch, 378th batch
# 1th epoch, 379th batch
# 1th epoch, 380th batch
# 1th epoch, 381th batch
# 1th epoch, 382th batch
# 1th epoch, 383th batch
# 1th epoch, 384th batch
# 1th epoch, 385th batch
# 1th epoch, 386th batch
# 1th epoch, 387th batch
# 1th epoch, 388th batch
# 1th epoch, 389th batch
# 1th epoch, 390th batch
# 1th epoch, 391th batch
# 1th epoch, 392th batch
# 1th epoch, 393th batch
# 1th epoch, 394th batch
# 1th epoch, 395th batch
# 1th epoch, 396th batch
# 1th epoch, 397th batch
# 1th epoch, 398th batch
# 1th epoch, 399th batch
# 1th epoch, 400th batch
# 1th epoch, 401th batch
# 1th epoch, 402th batch
# 1th epoch, 403th batch
# 1th epoch, 404th batch
# 1th epoch, 405th batch
# 1th epoch, 406th batch
# 1th epoch, 407th batch
# 1th epoch, 408th batch
# 1th epoch, 409th batch
# 1th epoch, 410th batch
# 1th epoch, 411th batch
# 1th epoch, 412th batch
# 1th epoch, 413th batch
# 1th epoch, 414th batch
# 1th epoch, 415th batch
# 1th epoch, 416th batch
# 1th epoch, 417th batch
# 1th epoch, 418th batch
# 1th epoch, 419th batch
# 1th epoch, 420th batch
# 1th epoch, 421th batch
# 1th epoch, 422th batch
# 1th epoch, 423th batch
# 1th epoch, 424th batch
# 1th epoch, 425th batch
# 1th epoch, 426th batch
# 1th epoch, 427th batch
# 1th epoch, 428th batch
# 1th epoch, 429th batch
# 1th epoch, 430th batch
# 1th epoch, 431th batch
# 1th epoch, 432th batch
# 1th epoch, 433th batch
# 1th epoch, 434th batch
# 1th epoch, 435th batch
# 1th epoch, 436th batch
# 1th epoch, 437th batch
# 1th epoch, 438th batch
# 1th epoch, 439th batch
# 1th epoch, 440th batch
# 1th epoch, 441th batch
# 1th epoch, 442th batch
# 1th epoch, 443th batch
# 1th epoch, 444th batch
# 1th epoch, 445th batch
# 1th epoch, 446th batch
# 1th epoch, 447th batch
# 1th epoch, 448th batch
# 1th epoch, 449th batch
# 1th epoch, 450th batch
# 1th epoch, 451th batch
# 1th epoch, 452th batch
# 1th epoch, 453th batch
# 1th epoch, 454th batch
# 1th epoch, 455th batch
# 1th epoch, 456th batch
# 1th epoch, 457th batch
# 1th epoch, 458th batch
# 1th epoch, 459th batch
# 1th epoch, 460th batch
# 1th epoch, 461th batch
# 1th epoch, 462th batch
# 1th epoch, 463th batch
# 1th epoch, 464th batch
# 1th epoch, 465th batch
# 1th epoch, 466th batch
# 1th epoch, 467th batch
# 1th epoch, 468th batch
# 1th epoch, 469th batch
# 1th epoch, 470th batch
# 1th epoch, 471th batch
# 1th epoch, 472th batch
# 1th epoch, 473th batch
# 1th epoch, 474th batch
# 1th epoch, 475th batch
# 1th epoch, 476th batch
# 1th epoch, 477th batch
# 1th epoch, 478th batch
# 1th epoch, 479th batch
# 1th epoch, 480th batch
# 1th epoch, 481th batch
# 1th epoch, 482th batch
# 1th epoch, 483th batch
# 1th epoch, 484th batch
# 1th epoch, 485th batch
# 1th epoch, 486th batch
# 1th epoch, 487th batch
# 1th epoch, 488th batch
# 1th epoch, 489th batch
# 1th epoch, 490th batch
# 1th epoch, 491th batch
# 1th epoch, 492th batch
# 1th epoch, 493th batch
# 1th epoch, 494th batch
# 1th epoch, 495th batch
# 1th epoch, 496th batch
# 1th epoch, 497th batch
# 1th epoch, 498th batch
# 1th epoch, 499th batch
# 1th epoch, 500th batch
# 1th epoch, 501th batch
# 1th epoch, 502th batch
# 1th epoch, 503th batch
# 1th epoch, 504th batch
# 1th epoch, 505th batch
# 1th epoch, 506th batch
# 1th epoch, 507th batch
# 1th epoch, 508th batch
# 1th epoch, 509th batch
# 1th epoch, 510th batch
# 1th epoch, 511th batch
# 1th epoch, 512th batch
# 1th epoch, 513th batch
# 1th epoch, 514th batch
# 1th epoch, 515th batch
# 1th epoch, 516th batch
# 1th epoch, 517th batch
# 1th epoch, 518th batch
# 1th epoch, 519th batch
# 1th epoch, 520th batch
# 1th epoch, 521th batch
# 1th epoch, 522th batch
# 1th epoch, 523th batch
# 1th epoch, 524th batch
# 1th epoch, 525th batch
# 1th epoch, 526th batch
# 1th epoch, 527th batch
# 1th epoch, 528th batch
# 1th epoch, 529th batch
# 1th epoch, 530th batch
# 1th epoch, 531th batch
# 1th epoch, 532th batch
# 1th epoch, 533th batch
# 1th epoch, 534th batch
# 1th epoch, 535th batch
# 1th epoch, 536th batch
# 1th epoch, 537th batch
# 1th epoch, 538th batch
# 1th epoch, 539th batch
# 1th epoch, 540th batch
# 1th epoch, 541th batch
# 1th epoch, 542th batch
# 1th epoch, 543th batch
# 1th epoch, 544th batch
# 1th epoch, 545th batch
# 1th epoch, 546th batch
# 1th epoch, 547th batch
# 1th epoch, 548th batch
# 1th epoch, 549th batch
# 1th epoch, 550th batch
# 1th epoch, 551th batch
# 1th epoch, 552th batch
# 1th epoch, 553th batch
# 1th epoch, 554th batch
# 1th epoch, 555th batch
# 1th epoch, 556th batch
# 1th epoch, 557th batch
# 1th epoch, 558th batch
# 1th epoch, 559th batch
# 1th epoch, 560th batch
# 1th epoch, 561th batch
# 1th epoch, 562th batch
# 1th epoch, 563th batch
# 1th epoch, 564th batch
# 1th epoch, 565th batch
# 1th epoch, 566th batch
# 1th epoch, 567th batch
# 1th epoch, 568th batch
# 1th epoch, 569th batch
# 1th epoch, 570th batch
# 1th epoch, 571th batch
# 1th epoch, 572th batch
# 1th epoch, 573th batch
# 1th epoch, 574th batch
# 1th epoch, 575th batch
# 1th epoch, 576th batch
# 1th epoch, 577th batch
# 1th epoch, 578th batch
# 1th epoch, 579th batch
# 1th epoch, 580th batch
# 1th epoch, 581th batch
# 1th epoch, 582th batch
# 1th epoch, 583th batch
# 1th epoch, 584th batch
# 1th epoch, 585th batch
# 1th epoch, 586th batch
# 1th epoch, 587th batch
# 1th epoch, 588th batch
# 1th epoch, 589th batch
# 1th epoch, 590th batch
# 1th epoch, 591th batch
# 1th epoch, 592th batch
# 1th epoch, 593th batch
# 1th epoch, 594th batch
# 1th epoch, 595th batch
# 1th epoch, 596th batch
# 1th epoch, 597th batch
# 1th epoch, 598th batch
# 1th epoch, 599th batch
# 1th epoch, 600th batch
# 1th epoch, 601th batch
# 1th epoch, 602th batch
# 1th epoch, 603th batch
# 1th epoch, 604th batch
# 1th epoch, 605th batch
# 1th epoch, 606th batch
# 1th epoch, 607th batch
# 1th epoch, 608th batch
# 1th epoch, 609th batch
# 1th epoch, 610th batch
# 1th epoch, 611th batch
# 1th epoch, 612th batch
# 1th epoch, 613th batch
# 1th epoch, 614th batch
# 1th epoch, 615th batch
# 1th epoch, 616th batch
# 1th epoch, 617th batch
# 1th epoch, 618th batch
# 1th epoch, 619th batch
# 1th epoch, 620th batch
# 1th epoch, 621th batch
# 1th epoch, 622th batch
# 1th epoch, 623th batch
# 1th epoch, 624th batch
# 1th epoch, 625th batch
# 1th epoch, 626th batch
# 1th epoch, 627th batch
# 1th epoch, 628th batch
# 1th epoch, 629th batch
# 1th epoch, 630th batch
# 1th epoch, 631th batch
# 1th epoch, 632th batch
# 1th epoch, 633th batch
# 1th epoch, 634th batch
# 1th epoch, 635th batch
# 1th epoch, 636th batch
# 1th epoch, 637th batch
# 1th epoch, 638th batch
# 1th epoch, 639th batch
# 1th epoch, 640th batch
# 1th epoch, 641th batch
# 1th epoch, 642th batch
# 1th epoch, 643th batch
# 1th epoch, 644th batch
# 1th epoch, 645th batch
# 1th epoch, 646th batch
# 1th epoch, 647th batch
# 1th epoch, 648th batch
# 1th epoch, 649th batch
# 1th epoch, 650th batch
# 1th epoch, 651th batch
# 1th epoch, 652th batch
# 1th epoch, 653th batch
# 1th epoch, 654th batch
# 1th epoch, 655th batch
# 1th epoch, 656th batch
# 1th epoch, 657th batch
# 1th epoch, 658th batch
# 1th epoch, 659th batch
# 1th epoch, 660th batch
# 1th epoch, 661th batch
# 1th epoch, 662th batch
# 1th epoch, 663th batch
# 1th epoch, 664th batch
# 1th epoch, 665th batch
# 1th epoch, 666th batch
# 1th epoch, 667th batch
# 1th epoch, 668th batch
# 1th epoch, 669th batch
# 1th epoch, 670th batch
# 1th epoch, 671th batch
# 1th epoch, 672th batch
# 1th epoch, 673th batch
# 1th epoch, 674th batch
# 1th epoch, 675th batch
# 1th epoch, 676th batch
# 1th epoch, 677th batch
# 1th epoch, 678th batch
# 1th epoch, 679th batch
# 1th epoch, 680th batch
# 1th epoch, 681th batch
# 1th epoch, 682th batch
# 1th epoch, 683th batch
# 1th epoch, 684th batch
# 1th epoch, 685th batch
# 1th epoch, 686th batch
# 1th epoch, 687th batch
# 1th epoch, 688th batch
# 1th epoch, 689th batch
# 1th epoch, 690th batch
# 1th epoch, 691th batch
# 1th epoch, 692th batch
# 1th epoch, 693th batch
# 1th epoch, 694th batch
# 1th epoch, 695th batch
# 1th epoch, 696th batch
# 1th epoch, 697th batch
# 1th epoch, 698th batch
# 1th epoch, 699th batch
# 1th epoch, 700th batch
# 1th epoch, 701th batch
# 1th epoch, 702th batch
# 1th epoch, 703th batch
# 1th epoch, 704th batch
# 1th epoch, 705th batch
# 1th epoch, 706th batch
# 1th epoch, 707th batch
# 1th epoch, 708th batch
# 1th epoch, 709th batch
# 1th epoch, 710th batch
# 1th epoch, 711th batch
# 1th epoch, 712th batch
# 1th epoch, 713th batch
# 1th epoch, 714th batch
# 1th epoch, 715th batch
# 1th epoch, 716th batch
# 1th epoch, 717th batch
# 1th epoch, 718th batch
# 1th epoch, 719th batch
# 1th epoch, 720th batch
# 1th epoch, 721th batch
# 1th epoch, 722th batch
# 1th epoch, 723th batch
# 1th epoch, 724th batch
# 1th epoch, 725th batch
# 1th epoch, 726th batch
# 1th epoch, 727th batch
# 1th epoch, 728th batch
# 1th epoch, 729th batch
# 1th epoch, 730th batch
# 1th epoch, 731th batch
# 1th epoch, 732th batch
# 1th epoch, 733th batch
# 1th epoch, 734th batch
# 1th epoch, 735th batch
# 1th epoch, 736th batch
# 1th epoch, 737th batch
# 1th epoch, 738th batch
# 1th epoch, 739th batch
# 1th epoch, 740th batch
# 1th epoch, 741th batch
# 1th epoch, 742th batch
# 1th epoch, 743th batch
# 1th epoch, 744th batch
# 1th epoch, 745th batch
# 1th epoch, 746th batch
# 1th epoch, 747th batch
# 1th epoch, 748th batch
# 1th epoch, 749th batch
# 1th epoch, 750th batch
# 1th epoch, 751th batch
# 1th epoch, 752th batch
# 1th epoch, 753th batch
# 1th epoch, 754th batch
# 1th epoch, 755th batch
# 1th epoch, 756th batch
# 1th epoch, 757th batch
# 1th epoch, 758th batch
# 1th epoch, 759th batch
# 1th epoch, 760th batch
# 1th epoch, 761th batch
# 1th epoch, 762th batch
# 1th epoch, 763th batch
# 1th epoch, 764th batch
# 1th epoch, 765th batch
# 1th epoch, 766th batch
# 1th epoch, 767th batch
# 1th epoch, 768th batch
# 1th epoch, 769th batch
# 1th epoch, 770th batch
# 1th epoch, 771th batch
# 1th epoch, 772th batch
# 1th epoch, 773th batch
# 1th epoch, 774th batch
# 1th epoch, 775th batch
# 1th epoch, 776th batch
# 1th epoch, 777th batch
# 1th epoch, 778th batch
# 1th epoch, 779th batch
# 1th epoch, 780th batch
# 1th epoch, 781th batch
# 1th epoch, 782th batch
# 1th epoch, 783th batch
# 1th epoch, 784th batch
# 1th epoch, 785th batch
# 1th epoch, 786th batch
# 1th epoch, 787th batch
# 1th epoch, 788th batch
# 1th epoch, 789th batch
# 1th epoch, 790th batch
# 1th epoch, 791th batch
# 1th epoch, 792th batch
# 1th epoch, 793th batch
# 1th epoch, 794th batch
# 1th epoch, 795th batch
# 1th epoch, 796th batch
# 1th epoch, 797th batch
# 1th epoch, 798th batch
# 1th epoch, 799th batch
# 2th epoch, 0th batch
# 2th epoch, 1th batch
# 2th epoch, 2th batch
# 2th epoch, 3th batch
# 2th epoch, 4th batch
# 2th epoch, 5th batch
# 2th epoch, 6th batch
# 2th epoch, 7th batch
# 2th epoch, 8th batch
# 2th epoch, 9th batch
# 2th epoch, 10th batch
# 2th epoch, 11th batch
# 2th epoch, 12th batch
# 2th epoch, 13th batch
# 2th epoch, 14th batch
# 2th epoch, 15th batch
# 2th epoch, 16th batch
# 2th epoch, 17th batch
# 2th epoch, 18th batch
# 2th epoch, 19th batch
# 2th epoch, 20th batch
# 2th epoch, 21th batch
# 2th epoch, 22th batch
# 2th epoch, 23th batch
# 2th epoch, 24th batch
# 2th epoch, 25th batch
# 2th epoch, 26th batch
# 2th epoch, 27th batch
# 2th epoch, 28th batch
# 2th epoch, 29th batch
# 2th epoch, 30th batch
# 2th epoch, 31th batch
# 2th epoch, 32th batch
# 2th epoch, 33th batch
# 2th epoch, 34th batch
# 2th epoch, 35th batch
# 2th epoch, 36th batch
# 2th epoch, 37th batch
# 2th epoch, 38th batch
# 2th epoch, 39th batch
# 2th epoch, 40th batch
# 2th epoch, 41th batch
# 2th epoch, 42th batch
# 2th epoch, 43th batch
# 2th epoch, 44th batch
# 2th epoch, 45th batch
# 2th epoch, 46th batch
# 2th epoch, 47th batch
# 2th epoch, 48th batch
# 2th epoch, 49th batch
# 2th epoch, 50th batch
# 2th epoch, 51th batch
# 2th epoch, 52th batch
# 2th epoch, 53th batch
# 2th epoch, 54th batch
# 2th epoch, 55th batch
# 2th epoch, 56th batch
# 2th epoch, 57th batch
# 2th epoch, 58th batch
# 2th epoch, 59th batch
# 2th epoch, 60th batch
# 2th epoch, 61th batch
# 2th epoch, 62th batch
# 2th epoch, 63th batch
# 2th epoch, 64th batch
# 2th epoch, 65th batch
# 2th epoch, 66th batch
# 2th epoch, 67th batch
# 2th epoch, 68th batch
# 2th epoch, 69th batch
# 2th epoch, 70th batch
# 2th epoch, 71th batch
# 2th epoch, 72th batch
# 2th epoch, 73th batch
# 2th epoch, 74th batch
# 2th epoch, 75th batch
# 2th epoch, 76th batch
# 2th epoch, 77th batch
# 2th epoch, 78th batch
# 2th epoch, 79th batch
# 2th epoch, 80th batch
# 2th epoch, 81th batch
# 2th epoch, 82th batch
# 2th epoch, 83th batch
# 2th epoch, 84th batch
# 2th epoch, 85th batch
# 2th epoch, 86th batch
# 2th epoch, 87th batch
# 2th epoch, 88th batch
# 2th epoch, 89th batch
# 2th epoch, 90th batch
# 2th epoch, 91th batch
# 2th epoch, 92th batch
# 2th epoch, 93th batch
# 2th epoch, 94th batch
# 2th epoch, 95th batch
# 2th epoch, 96th batch
# 2th epoch, 97th batch
# 2th epoch, 98th batch
# 2th epoch, 99th batch
# 2th epoch, 100th batch
# 2th epoch, 101th batch
# 2th epoch, 102th batch
# 2th epoch, 103th batch
# 2th epoch, 104th batch
# 2th epoch, 105th batch
# 2th epoch, 106th batch
# 2th epoch, 107th batch
# 2th epoch, 108th batch
# 2th epoch, 109th batch
# 2th epoch, 110th batch
# 2th epoch, 111th batch
# 2th epoch, 112th batch
# 2th epoch, 113th batch
# 2th epoch, 114th batch
# 2th epoch, 115th batch
# 2th epoch, 116th batch
# 2th epoch, 117th batch
# 2th epoch, 118th batch
# 2th epoch, 119th batch
# 2th epoch, 120th batch
# 2th epoch, 121th batch
# 2th epoch, 122th batch
# 2th epoch, 123th batch
# 2th epoch, 124th batch
# 2th epoch, 125th batch
# 2th epoch, 126th batch
# 2th epoch, 127th batch
# 2th epoch, 128th batch
# 2th epoch, 129th batch
# 2th epoch, 130th batch
# 2th epoch, 131th batch
# 2th epoch, 132th batch
# 2th epoch, 133th batch
# 2th epoch, 134th batch
# 2th epoch, 135th batch
# 2th epoch, 136th batch
# 2th epoch, 137th batch
# 2th epoch, 138th batch
# 2th epoch, 139th batch
# 2th epoch, 140th batch
# 2th epoch, 141th batch
# 2th epoch, 142th batch
# 2th epoch, 143th batch
# 2th epoch, 144th batch
# 2th epoch, 145th batch
# 2th epoch, 146th batch
# 2th epoch, 147th batch
# 2th epoch, 148th batch
# 2th epoch, 149th batch
# 2th epoch, 150th batch
# 2th epoch, 151th batch
# 2th epoch, 152th batch
# 2th epoch, 153th batch
# 2th epoch, 154th batch
# 2th epoch, 155th batch
# 2th epoch, 156th batch
# 2th epoch, 157th batch
# 2th epoch, 158th batch
# 2th epoch, 159th batch
# 2th epoch, 160th batch
# 2th epoch, 161th batch
# 2th epoch, 162th batch
# 2th epoch, 163th batch
# 2th epoch, 164th batch
# 2th epoch, 165th batch
# 2th epoch, 166th batch
# 2th epoch, 167th batch
# 2th epoch, 168th batch
# 2th epoch, 169th batch
# 2th epoch, 170th batch
# 2th epoch, 171th batch
# 2th epoch, 172th batch
# 2th epoch, 173th batch
# 2th epoch, 174th batch
# 2th epoch, 175th batch
# 2th epoch, 176th batch
# 2th epoch, 177th batch
# 2th epoch, 178th batch
# 2th epoch, 179th batch
# 2th epoch, 180th batch
# 2th epoch, 181th batch
# 2th epoch, 182th batch
# 2th epoch, 183th batch
# 2th epoch, 184th batch
# 2th epoch, 185th batch
# 2th epoch, 186th batch
# 2th epoch, 187th batch
# 2th epoch, 188th batch
# 2th epoch, 189th batch
# 2th epoch, 190th batch
# 2th epoch, 191th batch
# 2th epoch, 192th batch
# 2th epoch, 193th batch
# 2th epoch, 194th batch
# 2th epoch, 195th batch
# 2th epoch, 196th batch
# 2th epoch, 197th batch
# 2th epoch, 198th batch
# 2th epoch, 199th batch
# 2th epoch, 200th batch
# 2th epoch, 201th batch
# 2th epoch, 202th batch
# 2th epoch, 203th batch
# 2th epoch, 204th batch
# 2th epoch, 205th batch
# 2th epoch, 206th batch
# 2th epoch, 207th batch
# 2th epoch, 208th batch
# 2th epoch, 209th batch
# 2th epoch, 210th batch
# 2th epoch, 211th batch
# 2th epoch, 212th batch
# 2th epoch, 213th batch
# 2th epoch, 214th batch
# 2th epoch, 215th batch
# 2th epoch, 216th batch
# 2th epoch, 217th batch
# 2th epoch, 218th batch
# 2th epoch, 219th batch
# 2th epoch, 220th batch
# 2th epoch, 221th batch
# 2th epoch, 222th batch
# 2th epoch, 223th batch
# 2th epoch, 224th batch
# 2th epoch, 225th batch
# 2th epoch, 226th batch
# 2th epoch, 227th batch
# 2th epoch, 228th batch
# 2th epoch, 229th batch
# 2th epoch, 230th batch
# 2th epoch, 231th batch
# 2th epoch, 232th batch
# 2th epoch, 233th batch
# 2th epoch, 234th batch
# 2th epoch, 235th batch
# 2th epoch, 236th batch
# 2th epoch, 237th batch
# 2th epoch, 238th batch
# 2th epoch, 239th batch
# 2th epoch, 240th batch
# 2th epoch, 241th batch
# 2th epoch, 242th batch
# 2th epoch, 243th batch
# 2th epoch, 244th batch
# 2th epoch, 245th batch
# 2th epoch, 246th batch
# 2th epoch, 247th batch
# 2th epoch, 248th batch
# 2th epoch, 249th batch
# 2th epoch, 250th batch
# 2th epoch, 251th batch
# 2th epoch, 252th batch
# 2th epoch, 253th batch
# 2th epoch, 254th batch
# 2th epoch, 255th batch
# 2th epoch, 256th batch
# 2th epoch, 257th batch
# 2th epoch, 258th batch
# 2th epoch, 259th batch
# 2th epoch, 260th batch
# 2th epoch, 261th batch
# 2th epoch, 262th batch
# 2th epoch, 263th batch
# 2th epoch, 264th batch
# 2th epoch, 265th batch
# 2th epoch, 266th batch
# 2th epoch, 267th batch
# 2th epoch, 268th batch
# 2th epoch, 269th batch
# 2th epoch, 270th batch
# 2th epoch, 271th batch
# 2th epoch, 272th batch
# 2th epoch, 273th batch
# 2th epoch, 274th batch
# 2th epoch, 275th batch
# 2th epoch, 276th batch
# 2th epoch, 277th batch
# 2th epoch, 278th batch
# 2th epoch, 279th batch
# 2th epoch, 280th batch
# 2th epoch, 281th batch
# 2th epoch, 282th batch
# 2th epoch, 283th batch
# 2th epoch, 284th batch
# 2th epoch, 285th batch
# 2th epoch, 286th batch
# 2th epoch, 287th batch
# 2th epoch, 288th batch
# 2th epoch, 289th batch
# 2th epoch, 290th batch
# 2th epoch, 291th batch
# 2th epoch, 292th batch
# 2th epoch, 293th batch
# 2th epoch, 294th batch
# 2th epoch, 295th batch
# 2th epoch, 296th batch
# 2th epoch, 297th batch
# 2th epoch, 298th batch
# 2th epoch, 299th batch
# 2th epoch, 300th batch
# 2th epoch, 301th batch
# 2th epoch, 302th batch
# 2th epoch, 303th batch
# 2th epoch, 304th batch
# 2th epoch, 305th batch
# 2th epoch, 306th batch
# 2th epoch, 307th batch
# 2th epoch, 308th batch
# 2th epoch, 309th batch
# 2th epoch, 310th batch
# 2th epoch, 311th batch
# 2th epoch, 312th batch
# 2th epoch, 313th batch
# 2th epoch, 314th batch
# 2th epoch, 315th batch
# 2th epoch, 316th batch
# 2th epoch, 317th batch
# 2th epoch, 318th batch
# 2th epoch, 319th batch
# 2th epoch, 320th batch
# 2th epoch, 321th batch
# 2th epoch, 322th batch
# 2th epoch, 323th batch
# 2th epoch, 324th batch
# 2th epoch, 325th batch
# 2th epoch, 326th batch
# 2th epoch, 327th batch
# 2th epoch, 328th batch
# 2th epoch, 329th batch
# 2th epoch, 330th batch
# 2th epoch, 331th batch
# 2th epoch, 332th batch
# 2th epoch, 333th batch
# 2th epoch, 334th batch
# 2th epoch, 335th batch
# 2th epoch, 336th batch
# 2th epoch, 337th batch
# 2th epoch, 338th batch
# 2th epoch, 339th batch
# 2th epoch, 340th batch
# 2th epoch, 341th batch
# 2th epoch, 342th batch
# 2th epoch, 343th batch
# 2th epoch, 344th batch
# 2th epoch, 345th batch
# 2th epoch, 346th batch
# 2th epoch, 347th batch
# 2th epoch, 348th batch
# 2th epoch, 349th batch
# 2th epoch, 350th batch
# 2th epoch, 351th batch
# 2th epoch, 352th batch
# 2th epoch, 353th batch
# 2th epoch, 354th batch
# 2th epoch, 355th batch
# 2th epoch, 356th batch
# 2th epoch, 357th batch
# 2th epoch, 358th batch
# 2th epoch, 359th batch
# 2th epoch, 360th batch
# 2th epoch, 361th batch
# 2th epoch, 362th batch
# 2th epoch, 363th batch
# 2th epoch, 364th batch
# 2th epoch, 365th batch
# 2th epoch, 366th batch
# 2th epoch, 367th batch
# 2th epoch, 368th batch
# 2th epoch, 369th batch
# 2th epoch, 370th batch
# 2th epoch, 371th batch
# 2th epoch, 372th batch
# 2th epoch, 373th batch
# 2th epoch, 374th batch
# 2th epoch, 375th batch
# 2th epoch, 376th batch
# 2th epoch, 377th batch
# 2th epoch, 378th batch
# 2th epoch, 379th batch
# 2th epoch, 380th batch
# 2th epoch, 381th batch
# 2th epoch, 382th batch
# 2th epoch, 383th batch
# 2th epoch, 384th batch
# 2th epoch, 385th batch
# 2th epoch, 386th batch
# 2th epoch, 387th batch
# 2th epoch, 388th batch
# 2th epoch, 389th batch
# 2th epoch, 390th batch
# 2th epoch, 391th batch
# 2th epoch, 392th batch
# 2th epoch, 393th batch
# 2th epoch, 394th batch
# 2th epoch, 395th batch
# 2th epoch, 396th batch
# 2th epoch, 397th batch
# 2th epoch, 398th batch
# 2th epoch, 399th batch
# 2th epoch, 400th batch
# 2th epoch, 401th batch
# 2th epoch, 402th batch
# 2th epoch, 403th batch
# 2th epoch, 404th batch
# 2th epoch, 405th batch
# 2th epoch, 406th batch
# 2th epoch, 407th batch
# 2th epoch, 408th batch
# 2th epoch, 409th batch
# 2th epoch, 410th batch
# 2th epoch, 411th batch
# 2th epoch, 412th batch
# 2th epoch, 413th batch
# 2th epoch, 414th batch
# 2th epoch, 415th batch
# 2th epoch, 416th batch
# 2th epoch, 417th batch
# 2th epoch, 418th batch
# 2th epoch, 419th batch
# 2th epoch, 420th batch
# 2th epoch, 421th batch
# 2th epoch, 422th batch
# 2th epoch, 423th batch
# 2th epoch, 424th batch
# 2th epoch, 425th batch
# 2th epoch, 426th batch
# 2th epoch, 427th batch
# 2th epoch, 428th batch
# 2th epoch, 429th batch
# 2th epoch, 430th batch
# 2th epoch, 431th batch
# 2th epoch, 432th batch
# 2th epoch, 433th batch
# 2th epoch, 434th batch
# 2th epoch, 435th batch
# 2th epoch, 436th batch
# 2th epoch, 437th batch
# 2th epoch, 438th batch
# 2th epoch, 439th batch
# 2th epoch, 440th batch
# 2th epoch, 441th batch
# 2th epoch, 442th batch
# 2th epoch, 443th batch
# 2th epoch, 444th batch
# 2th epoch, 445th batch
# 2th epoch, 446th batch
# 2th epoch, 447th batch
# 2th epoch, 448th batch
# 2th epoch, 449th batch
# 2th epoch, 450th batch
# 2th epoch, 451th batch
# 2th epoch, 452th batch
# 2th epoch, 453th batch
# 2th epoch, 454th batch
# 2th epoch, 455th batch
# 2th epoch, 456th batch
# 2th epoch, 457th batch
# 2th epoch, 458th batch
# 2th epoch, 459th batch
# 2th epoch, 460th batch
# 2th epoch, 461th batch
# 2th epoch, 462th batch
# 2th epoch, 463th batch
# 2th epoch, 464th batch
# 2th epoch, 465th batch
# 2th epoch, 466th batch
# 2th epoch, 467th batch
# 2th epoch, 468th batch
# 2th epoch, 469th batch
# 2th epoch, 470th batch
# 2th epoch, 471th batch
# 2th epoch, 472th batch
# 2th epoch, 473th batch
# 2th epoch, 474th batch
# 2th epoch, 475th batch
# 2th epoch, 476th batch
# 2th epoch, 477th batch
# 2th epoch, 478th batch
# 2th epoch, 479th batch
# 2th epoch, 480th batch
# 2th epoch, 481th batch
# 2th epoch, 482th batch
# 2th epoch, 483th batch
# 2th epoch, 484th batch
# 2th epoch, 485th batch
# 2th epoch, 486th batch
# 2th epoch, 487th batch
# 2th epoch, 488th batch
# 2th epoch, 489th batch
# 2th epoch, 490th batch
# 2th epoch, 491th batch
# 2th epoch, 492th batch
# 2th epoch, 493th batch
# 2th epoch, 494th batch
# 2th epoch, 495th batch
# 2th epoch, 496th batch
# 2th epoch, 497th batch
# 2th epoch, 498th batch
# ...
# 99th epoch, 135th batch
# 99th epoch, 136th batch
# 99th epoch, 137th batch
# 99th epoch, 138th batch
# 99th epoch, 139th batch
# 99th epoch, 140th batch
# 99th epoch, 141th batch
# 99th epoch, 142th batch
# 99th epoch, 143th batch
# 99th epoch, 144th batch
# 99th epoch, 145th batch
# 99th epoch, 146th batch
# 99th epoch, 147th batch
# 99th epoch, 148th batch
# 99th epoch, 149th batch
# 99th epoch, 150th batch
# 99th epoch, 151th batch
# 99th epoch, 152th batch
# 99th epoch, 153th batch
# 99th epoch, 154th batch
# 99th epoch, 155th batch
# 99th epoch, 156th batch
# 99th epoch, 157th batch
# 99th epoch, 158th batch
# 99th epoch, 159th batch
# 99th epoch, 160th batch
# 99th epoch, 161th batch
# 99th epoch, 162th batch
# 99th epoch, 163th batch
# 99th epoch, 164th batch
# 99th epoch, 165th batch
# 99th epoch, 166th batch
# 99th epoch, 167th batch
# 99th epoch, 168th batch
# 99th epoch, 169th batch
# 99th epoch, 170th batch
# 99th epoch, 171th batch
# 99th epoch, 172th batch
# 99th epoch, 173th batch
# 99th epoch, 174th batch
# 99th epoch, 175th batch
# 99th epoch, 176th batch
# 99th epoch, 177th batch
# 99th epoch, 178th batch
# 99th epoch, 179th batch
# 99th epoch, 180th batch
# 99th epoch, 181th batch
# 99th epoch, 182th batch
# 99th epoch, 183th batch
# 99th epoch, 184th batch
# 99th epoch, 185th batch
# 99th epoch, 186th batch
# 99th epoch, 187th batch
# 99th epoch, 188th batch
# 99th epoch, 189th batch
# 99th epoch, 190th batch
# 99th epoch, 191th batch
# 99th epoch, 192th batch
# 99th epoch, 193th batch
# 99th epoch, 194th batch
# 99th epoch, 195th batch
# 99th epoch, 196th batch
# 99th epoch, 197th batch
# 99th epoch, 198th batch
# 99th epoch, 199th batch
# 99th epoch, 200th batch
# 99th epoch, 201th batch
# 99th epoch, 202th batch
# 99th epoch, 203th batch
# 99th epoch, 204th batch
# 99th epoch, 205th batch
# 99th epoch, 206th batch
# 99th epoch, 207th batch
# 99th epoch, 208th batch
# 99th epoch, 209th batch
# 99th epoch, 210th batch
# 99th epoch, 211th batch
# 99th epoch, 212th batch
# 99th epoch, 213th batch
# 99th epoch, 214th batch
# 99th epoch, 215th batch
# 99th epoch, 216th batch
# 99th epoch, 217th batch
# 99th epoch, 218th batch
# 99th epoch, 219th batch
# 99th epoch, 220th batch
# 99th epoch, 221th batch
# 99th epoch, 222th batch
# 99th epoch, 223th batch
# 99th epoch, 224th batch
# 99th epoch, 225th batch
# 99th epoch, 226th batch
# 99th epoch, 227th batch
# 99th epoch, 228th batch
# 99th epoch, 229th batch
# 99th epoch, 230th batch
# 99th epoch, 231th batch
# 99th epoch, 232th batch
# 99th epoch, 233th batch
# 99th epoch, 234th batch
# 99th epoch, 235th batch
# 99th epoch, 236th batch
# 99th epoch, 237th batch
# 99th epoch, 238th batch
# 99th epoch, 239th batch
# 99th epoch, 240th batch
# 99th epoch, 241th batch
# 99th epoch, 242th batch
# 99th epoch, 243th batch
# 99th epoch, 244th batch
# 99th epoch, 245th batch
# 99th epoch, 246th batch
# 99th epoch, 247th batch
# 99th epoch, 248th batch
# 99th epoch, 249th batch
# 99th epoch, 250th batch
# 99th epoch, 251th batch
# 99th epoch, 252th batch
# 99th epoch, 253th batch
# 99th epoch, 254th batch
# 99th epoch, 255th batch
# 99th epoch, 256th batch
# 99th epoch, 257th batch
# 99th epoch, 258th batch
# 99th epoch, 259th batch
# 99th epoch, 260th batch
# 99th epoch, 261th batch
# 99th epoch, 262th batch
# 99th epoch, 263th batch
# 99th epoch, 264th batch
# 99th epoch, 265th batch
# 99th epoch, 266th batch
# 99th epoch, 267th batch
# 99th epoch, 268th batch
# 99th epoch, 269th batch
# 99th epoch, 270th batch
# 99th epoch, 271th batch
# 99th epoch, 272th batch
# 99th epoch, 273th batch
# 99th epoch, 274th batch
# 99th epoch, 275th batch
# 99th epoch, 276th batch
# 99th epoch, 277th batch
# 99th epoch, 278th batch
# 99th epoch, 279th batch
# 99th epoch, 280th batch
# 99th epoch, 281th batch
# 99th epoch, 282th batch
# 99th epoch, 283th batch
# 99th epoch, 284th batch
# 99th epoch, 285th batch
# 99th epoch, 286th batch
# 99th epoch, 287th batch
# 99th epoch, 288th batch
# 99th epoch, 289th batch
# 99th epoch, 290th batch
# 99th epoch, 291th batch
# 99th epoch, 292th batch
# 99th epoch, 293th batch
# 99th epoch, 294th batch
# 99th epoch, 295th batch
# 99th epoch, 296th batch
# 99th epoch, 297th batch
# 99th epoch, 298th batch
# 99th epoch, 299th batch
# 99th epoch, 300th batch
# 99th epoch, 301th batch
# 99th epoch, 302th batch
# 99th epoch, 303th batch
# 99th epoch, 304th batch
# 99th epoch, 305th batch
# 99th epoch, 306th batch
# 99th epoch, 307th batch
# 99th epoch, 308th batch
# 99th epoch, 309th batch
# 99th epoch, 310th batch
# 99th epoch, 311th batch
# 99th epoch, 312th batch
# 99th epoch, 313th batch
# 99th epoch, 314th batch
# 99th epoch, 315th batch
# 99th epoch, 316th batch
# 99th epoch, 317th batch
# 99th epoch, 318th batch
# 99th epoch, 319th batch
# 99th epoch, 320th batch
# 99th epoch, 321th batch
# 99th epoch, 322th batch
# 99th epoch, 323th batch
# 99th epoch, 324th batch
# 99th epoch, 325th batch
# 99th epoch, 326th batch
# 99th epoch, 327th batch
# 99th epoch, 328th batch
# 99th epoch, 329th batch
# 99th epoch, 330th batch
# 99th epoch, 331th batch
# 99th epoch, 332th batch
# 99th epoch, 333th batch
# 99th epoch, 334th batch
# 99th epoch, 335th batch
# 99th epoch, 336th batch
# 99th epoch, 337th batch
# 99th epoch, 338th batch
# 99th epoch, 339th batch
# 99th epoch, 340th batch
# 99th epoch, 341th batch
# 99th epoch, 342th batch
# 99th epoch, 343th batch
# 99th epoch, 344th batch
# 99th epoch, 345th batch
# 99th epoch, 346th batch
# 99th epoch, 347th batch
# 99th epoch, 348th batch
# 99th epoch, 349th batch
# 99th epoch, 350th batch
# 99th epoch, 351th batch
# 99th epoch, 352th batch
# 99th epoch, 353th batch
# 99th epoch, 354th batch
# 99th epoch, 355th batch
# 99th epoch, 356th batch
# 99th epoch, 357th batch
# 99th epoch, 358th batch
# 99th epoch, 359th batch
# 99th epoch, 360th batch
# 99th epoch, 361th batch
# 99th epoch, 362th batch
# 99th epoch, 363th batch
# 99th epoch, 364th batch
# 99th epoch, 365th batch
# 99th epoch, 366th batch
# 99th epoch, 367th batch
# 99th epoch, 368th batch
# 99th epoch, 369th batch
# 99th epoch, 370th batch
# 99th epoch, 371th batch
# 99th epoch, 372th batch
# 99th epoch, 373th batch
# 99th epoch, 374th batch
# 99th epoch, 375th batch
# 99th epoch, 376th batch
# 99th epoch, 377th batch
# 99th epoch, 378th batch
# 99th epoch, 379th batch
# 99th epoch, 380th batch
# 99th epoch, 381th batch
# 99th epoch, 382th batch
# 99th epoch, 383th batch
# 99th epoch, 384th batch
# 99th epoch, 385th batch
# 99th epoch, 386th batch
# 99th epoch, 387th batch
# 99th epoch, 388th batch
# 99th epoch, 389th batch
# 99th epoch, 390th batch
# 99th epoch, 391th batch
# 99th epoch, 392th batch
# 99th epoch, 393th batch
# 99th epoch, 394th batch
# 99th epoch, 395th batch
# 99th epoch, 396th batch
# 99th epoch, 397th batch
# 99th epoch, 398th batch
# 99th epoch, 399th batch
# 99th epoch, 400th batch
# 99th epoch, 401th batch
# 99th epoch, 402th batch
# 99th epoch, 403th batch
# 99th epoch, 404th batch
# 99th epoch, 405th batch
# 99th epoch, 406th batch
# 99th epoch, 407th batch
# 99th epoch, 408th batch
# 99th epoch, 409th batch
# 99th epoch, 410th batch
# 99th epoch, 411th batch
# 99th epoch, 412th batch
# 99th epoch, 413th batch
# 99th epoch, 414th batch
# 99th epoch, 415th batch
# 99th epoch, 416th batch
# 99th epoch, 417th batch
# 99th epoch, 418th batch
# 99th epoch, 419th batch
# 99th epoch, 420th batch
# 99th epoch, 421th batch
# 99th epoch, 422th batch
# 99th epoch, 423th batch
# 99th epoch, 424th batch
# 99th epoch, 425th batch
# 99th epoch, 426th batch
# 99th epoch, 427th batch
# 99th epoch, 428th batch
# 99th epoch, 429th batch
# 99th epoch, 430th batch
# 99th epoch, 431th batch
# 99th epoch, 432th batch
# 99th epoch, 433th batch
# 99th epoch, 434th batch
# 99th epoch, 435th batch
# 99th epoch, 436th batch
# 99th epoch, 437th batch
# 99th epoch, 438th batch
# 99th epoch, 439th batch
# 99th epoch, 440th batch
# 99th epoch, 441th batch
# 99th epoch, 442th batch
# 99th epoch, 443th batch
# 99th epoch, 444th batch
# 99th epoch, 445th batch
# 99th epoch, 446th batch
# 99th epoch, 447th batch
# 99th epoch, 448th batch
# 99th epoch, 449th batch
# 99th epoch, 450th batch
# 99th epoch, 451th batch
# 99th epoch, 452th batch
# 99th epoch, 453th batch
# 99th epoch, 454th batch
# 99th epoch, 455th batch
# 99th epoch, 456th batch
# 99th epoch, 457th batch
# 99th epoch, 458th batch
# 99th epoch, 459th batch
# 99th epoch, 460th batch
# 99th epoch, 461th batch
# 99th epoch, 462th batch
# 99th epoch, 463th batch
# 99th epoch, 464th batch
# 99th epoch, 465th batch
# 99th epoch, 466th batch
# 99th epoch, 467th batch
# 99th epoch, 468th batch
# 99th epoch, 469th batch
# 99th epoch, 470th batch
# 99th epoch, 471th batch
# 99th epoch, 472th batch
# 99th epoch, 473th batch
# 99th epoch, 474th batch
# 99th epoch, 475th batch
# 99th epoch, 476th batch
# 99th epoch, 477th batch
# 99th epoch, 478th batch
# 99th epoch, 479th batch
# 99th epoch, 480th batch
# 99th epoch, 481th batch
# 99th epoch, 482th batch
# 99th epoch, 483th batch
# 99th epoch, 484th batch
# 99th epoch, 485th batch
# 99th epoch, 486th batch
# 99th epoch, 487th batch
# 99th epoch, 488th batch
# 99th epoch, 489th batch
# 99th epoch, 490th batch
# 99th epoch, 491th batch
# 99th epoch, 492th batch
# 99th epoch, 493th batch
# 99th epoch, 494th batch
# 99th epoch, 495th batch
# 99th epoch, 496th batch
# 99th epoch, 497th batch
# 99th epoch, 498th batch
# 99th epoch, 499th batch
# 99th epoch, 500th batch
# 99th epoch, 501th batch
# 99th epoch, 502th batch
# 99th epoch, 503th batch
# 99th epoch, 504th batch
# 99th epoch, 505th batch
# 99th epoch, 506th batch
# 99th epoch, 507th batch
# 99th epoch, 508th batch
# 99th epoch, 509th batch
# 99th epoch, 510th batch
# 99th epoch, 511th batch
# 99th epoch, 512th batch
# 99th epoch, 513th batch
# 99th epoch, 514th batch
# 99th epoch, 515th batch
# 99th epoch, 516th batch
# 99th epoch, 517th batch
# 99th epoch, 518th batch
# 99th epoch, 519th batch
# 99th epoch, 520th batch
# 99th epoch, 521th batch
# 99th epoch, 522th batch
# 99th epoch, 523th batch
# 99th epoch, 524th batch
# 99th epoch, 525th batch
# 99th epoch, 526th batch
# 99th epoch, 527th batch
# 99th epoch, 528th batch
# 99th epoch, 529th batch
# 99th epoch, 530th batch
# 99th epoch, 531th batch
# 99th epoch, 532th batch
# 99th epoch, 533th batch
# 99th epoch, 534th batch
# 99th epoch, 535th batch
# 99th epoch, 536th batch
# 99th epoch, 537th batch
# 99th epoch, 538th batch
# 99th epoch, 539th batch
# 99th epoch, 540th batch
# 99th epoch, 541th batch
# 99th epoch, 542th batch
# 99th epoch, 543th batch
# 99th epoch, 544th batch
# 99th epoch, 545th batch
# 99th epoch, 546th batch
# 99th epoch, 547th batch
# 99th epoch, 548th batch
# 99th epoch, 549th batch
# 99th epoch, 550th batch
# 99th epoch, 551th batch
# 99th epoch, 552th batch
# 99th epoch, 553th batch
# 99th epoch, 554th batch
# 99th epoch, 555th batch
# 99th epoch, 556th batch
# 99th epoch, 557th batch
# 99th epoch, 558th batch
# 99th epoch, 559th batch
# 99th epoch, 560th batch
# 99th epoch, 561th batch
# 99th epoch, 562th batch
# 99th epoch, 563th batch
# 99th epoch, 564th batch
# 99th epoch, 565th batch
# 99th epoch, 566th batch
# 99th epoch, 567th batch
# 99th epoch, 568th batch
# 99th epoch, 569th batch
# 99th epoch, 570th batch
# 99th epoch, 571th batch
# 99th epoch, 572th batch
# 99th epoch, 573th batch
# 99th epoch, 574th batch
# 99th epoch, 575th batch
# 99th epoch, 576th batch
# 99th epoch, 577th batch
# 99th epoch, 578th batch
# 99th epoch, 579th batch
# 99th epoch, 580th batch
# 99th epoch, 581th batch
# 99th epoch, 582th batch
# 99th epoch, 583th batch
# 99th epoch, 584th batch
# 99th epoch, 585th batch
# 99th epoch, 586th batch
# 99th epoch, 587th batch
# 99th epoch, 588th batch
# 99th epoch, 589th batch
# 99th epoch, 590th batch
# 99th epoch, 591th batch
# 99th epoch, 592th batch
# 99th epoch, 593th batch
# 99th epoch, 594th batch
# 99th epoch, 595th batch
# 99th epoch, 596th batch
# 99th epoch, 597th batch
# 99th epoch, 598th batch
# 99th epoch, 599th batch
# 99th epoch, 600th batch
# 99th epoch, 601th batch
# 99th epoch, 602th batch
# 99th epoch, 603th batch
# 99th epoch, 604th batch
# 99th epoch, 605th batch
# 99th epoch, 606th batch
# 99th epoch, 607th batch
# 99th epoch, 608th batch
# 99th epoch, 609th batch
# 99th epoch, 610th batch
# 99th epoch, 611th batch
# 99th epoch, 612th batch
# 99th epoch, 613th batch
# 99th epoch, 614th batch
# 99th epoch, 615th batch
# 99th epoch, 616th batch
# 99th epoch, 617th batch
# 99th epoch, 618th batch
# 99th epoch, 619th batch
# 99th epoch, 620th batch
# 99th epoch, 621th batch
# 99th epoch, 622th batch
# 99th epoch, 623th batch
# 99th epoch, 624th batch
# 99th epoch, 625th batch
# 99th epoch, 626th batch
# 99th epoch, 627th batch
# 99th epoch, 628th batch
# 99th epoch, 629th batch
# 99th epoch, 630th batch
# 99th epoch, 631th batch
# 99th epoch, 632th batch
# 99th epoch, 633th batch
# 99th epoch, 634th batch
# 99th epoch, 635th batch
# 99th epoch, 636th batch
# 99th epoch, 637th batch
# 99th epoch, 638th batch
# 99th epoch, 639th batch
# 99th epoch, 640th batch
# 99th epoch, 641th batch
# 99th epoch, 642th batch
# 99th epoch, 643th batch
# 99th epoch, 644th batch
# 99th epoch, 645th batch
# 99th epoch, 646th batch
# 99th epoch, 647th batch
# 99th epoch, 648th batch
# 99th epoch, 649th batch
# 99th epoch, 650th batch
# 99th epoch, 651th batch
# 99th epoch, 652th batch
# 99th epoch, 653th batch
# 99th epoch, 654th batch
# 99th epoch, 655th batch
# 99th epoch, 656th batch
# 99th epoch, 657th batch
# 99th epoch, 658th batch
# 99th epoch, 659th batch
# 99th epoch, 660th batch
# 99th epoch, 661th batch
# 99th epoch, 662th batch
# 99th epoch, 663th batch
# 99th epoch, 664th batch
# 99th epoch, 665th batch
# 99th epoch, 666th batch
# 99th epoch, 667th batch
# 99th epoch, 668th batch
# 99th epoch, 669th batch
# 99th epoch, 670th batch
# 99th epoch, 671th batch
# 99th epoch, 672th batch
# 99th epoch, 673th batch
# 99th epoch, 674th batch
# 99th epoch, 675th batch
# 99th epoch, 676th batch
# 99th epoch, 677th batch
# 99th epoch, 678th batch
# 99th epoch, 679th batch
# 99th epoch, 680th batch
# 99th epoch, 681th batch
# 99th epoch, 682th batch
# 99th epoch, 683th batch
# 99th epoch, 684th batch
# 99th epoch, 685th batch
# 99th epoch, 686th batch
# 99th epoch, 687th batch
# 99th epoch, 688th batch
# 99th epoch, 689th batch
# 99th epoch, 690th batch
# 99th epoch, 691th batch
# 99th epoch, 692th batch
# 99th epoch, 693th batch
# 99th epoch, 694th batch
# 99th epoch, 695th batch
# 99th epoch, 696th batch
# 99th epoch, 697th batch
# 99th epoch, 698th batch
# 99th epoch, 699th batch
# 99th epoch, 700th batch
# 99th epoch, 701th batch
# 99th epoch, 702th batch
# 99th epoch, 703th batch
# 99th epoch, 704th batch
# 99th epoch, 705th batch
# 99th epoch, 706th batch
# 99th epoch, 707th batch
# 99th epoch, 708th batch
# 99th epoch, 709th batch
# 99th epoch, 710th batch
# 99th epoch, 711th batch
# 99th epoch, 712th batch
# 99th epoch, 713th batch
# 99th epoch, 714th batch
# 99th epoch, 715th batch
# 99th epoch, 716th batch
# 99th epoch, 717th batch
# 99th epoch, 718th batch
# 99th epoch, 719th batch
# 99th epoch, 720th batch
# 99th epoch, 721th batch
# 99th epoch, 722th batch
# 99th epoch, 723th batch
# 99th epoch, 724th batch
# 99th epoch, 725th batch
# 99th epoch, 726th batch
# 99th epoch, 727th batch
# 99th epoch, 728th batch
# 99th epoch, 729th batch
# 99th epoch, 730th batch
# 99th epoch, 731th batch
# 99th epoch, 732th batch
# 99th epoch, 733th batch
# 99th epoch, 734th batch
# 99th epoch, 735th batch
# 99th epoch, 736th batch
# 99th epoch, 737th batch
# 99th epoch, 738th batch
# 99th epoch, 739th batch
# 99th epoch, 740th batch
# 99th epoch, 741th batch
# 99th epoch, 742th batch
# 99th epoch, 743th batch
# 99th epoch, 744th batch
# 99th epoch, 745th batch
# 99th epoch, 746th batch
# 99th epoch, 747th batch
# 99th epoch, 748th batch
# 99th epoch, 749th batch
# 99th epoch, 750th batch
# 99th epoch, 751th batch
# 99th epoch, 752th batch
# 99th epoch, 753th batch
# 99th epoch, 754th batch
# 99th epoch, 755th batch
# 99th epoch, 756th batch
# 99th epoch, 757th batch
# 99th epoch, 758th batch
# 99th epoch, 759th batch
# 99th epoch, 760th batch
# 99th epoch, 761th batch
# 99th epoch, 762th batch
# 99th epoch, 763th batch
# 99th epoch, 764th batch
# 99th epoch, 765th batch
# 99th epoch, 766th batch
# 99th epoch, 767th batch
# 99th epoch, 768th batch
# 99th epoch, 769th batch
# 99th epoch, 770th batch
# 99th epoch, 771th batch
# 99th epoch, 772th batch
# 99th epoch, 773th batch
# 99th epoch, 774th batch
# 99th epoch, 775th batch
# 99th epoch, 776th batch
# 99th epoch, 777th batch
# 99th epoch, 778th batch
# 99th epoch, 779th batch
# 99th epoch, 780th batch
# 99th epoch, 781th batch
# 99th epoch, 782th batch
# 99th epoch, 783th batch
# 99th epoch, 784th batch
# 99th epoch, 785th batch
# 99th epoch, 786th batch
# 99th epoch, 787th batch
# 99th epoch, 788th batch
# 99th epoch, 789th batch
# 99th epoch, 790th batch
# 99th epoch, 791th batch
# 99th epoch, 792th batch
# 99th epoch, 793th batch
# 99th epoch, 794th batch
# 99th epoch, 795th batch
# 99th epoch, 796th batch
# 99th epoch, 797th batch
# 99th epoch, 798th batch
# 99th epoch, 799th batch
# Epoch: 100 / loss:0.046
